# %% [markdown]
# ## Global modules import

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import json
import numpy as np
from operator import itemgetter
import random as rnd
import sys
import torch

# %% [markdown]
# ## Local modules import

# %%
sys.path.append('..')

# %%
from data_loading import create_word_lists

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Loading data

# %%
sys.path.append('../data')

# %%
with open('../data/corpus_data.json') as json_file:
    data = json.load(json_file)
data = data['records']

# %%
human_transcripts = [entry['human_transcript'] for entry in data]
stt_transcripts   = [entry['stt_transcript'] for entry in data]

# %%
human_words, stt_words, word_labels, word_grams, word_sems = \
    create_word_lists(data)

# %% [markdown]
# # PIPELINE START
# ---

# %% [markdown]
# ## Train-test split

# %% [markdown]
# We need to extract which sentences contain German words in order to stratify the data split:

# %%
max_length = max(map(len, word_labels))
padded_labels = [row + [False] * (max_length - len(row)) for row in word_labels]
padded_labels = np.array(padded_labels)
stat_labels = np.any(padded_labels, axis=1)

# %% [markdown]
# Here, we split only indices and not data itself, because the data contains arrays of variable length, which does not work with `train_test_split`:

# %%
indices = list(range(len(human_transcripts)))
tr_indices, te_indices = train_test_split(indices, test_size=0.2, random_state=0, shuffle=True, stratify=stat_labels)

# %% [markdown]
# These are hepler functions that will extract data selected by indices:

# %%
extract_train = itemgetter(*tr_indices)
extract_test  = itemgetter(*te_indices)

# %% [markdown]
# Finally, do data splitting:

# %%
tr_human_transcripts = extract_train(human_transcripts) 
tr_stt_transcripts   = extract_train(stt_transcripts)
tr_human_words       = extract_train(human_words)
tr_stt_words         = extract_train(stt_words)

tr_word_labels       = extract_train(word_labels)
tr_word_grams        = extract_train(word_grams)
tr_word_sems         = extract_train(word_sems)

# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

te_human_transcripts = extract_test(human_transcripts) 
te_stt_transcripts   = extract_test(stt_transcripts)
te_human_words       = extract_test(human_words)
te_stt_words         = extract_test(stt_words)

te_word_labels       = extract_test(word_labels)
te_word_grams        = extract_test(word_grams)
te_word_sems         = extract_test(word_sems)

# %% [markdown]
# ## BERT part

# %% [markdown]
# Imports:

# %%
import torch
from transformers import BertTokenizer, BertModel

# %% [markdown]
# Load tokenizers. Make sure that the model outputs hidden states, as they will be used for word decoding. Also, set model to evaluation mode, as we will not train it. There is an option which we can test, which does not allow the splitting of words into multiple tokens. TODO.

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model_bert = BertModel.from_pretrained('bert-base-uncased', output_hidden_states=True)
model_bert.eval();

# %%
test_sentence = '[CLS]' + tr_stt_transcripts[23] + '[SEP]'  # Add special characters to denote start and end of sentence
tokens = tokenizer.tokenize(test_sentence)                  # Tokenize the sentence
indexed_tokens = tokenizer.convert_tokens_to_ids(tokens)    # Get dictionary indices for tokens
segments_ids = [1] * len(tokens)                            # The whole utterance is just one segment

# Next, convert the outputs to tensors
tokens_tensor = torch.tensor([indexed_tokens])
segments_tensors = torch.tensor([segments_ids])

# %%
with torch.no_grad():   # We aren't doing backprop
    outputs = model_bert(tokens_tensor, segments_tensors)

# %% [markdown]
# There are three things that the model outputs:

# %%
outputs.keys()
# Out:
# odict_keys(['last_hidden_state', 'pooler_output', 'hidden_states'])

# %% [markdown]
# We are interested in hidden states, of which there are

# %%
len(outputs.hidden_states)
# Out:
# 13

# %% [markdown]
# `output.hidden_layers` is a tuple of 13 tensors. Each tensor is three-dimensional. First dimension represents batches (sentences), second tokens and third individual values in a vector-encoded token.

# %% [markdown]
# The first layer consists of input embeddings, and the 12 remaining are BERT's layers.

# %%
outputs.hidden_states[1].shape
# Out:
# torch.Size([1, 39, 768])

# %%
outputs.hidden_states[0].shape[1] == len(tokens)
# Out:
# True

# %% [markdown]
# `hidden_states` was a tuple, so we make it a tensor. Furthermore, as our input contains just one sentence, we get rid of 'batches dimension'.

# %%
token_embeddings = torch.stack(hidden_states, dim=0)
token_embeddings = torch.squeeze(token_embeddings, dim=1)
token_embeddings = token_embeddings.permute(1,0,2)
token_embeddings = token_embeddings[1:-1]                   # We don't need [CLS] and [SEP]
token_embeddings.shape
# Out:
# torch.Size([37, 13, 768])

# %%
ts = torch.cat((token_embeddings[:, -4, :], token_embeddings[:, -3, :], token_embeddings[:, -2, :], token_embeddings[:, -1, :]), dim=1)
ts.shape
# Out:
# torch.Size([37, 3072])

# %% [markdown]
# Now, `token_embeddings` tensor contains all of the embeddings for each of our tokens. First dimension are tokens themselves, second dimension represents layers and the third one are embedding values.

# %% [markdown]
# Now we need to get a single vector to represent each token. This can be done in multiple ways, most important of which are
#
# - concatenation of last four layers
# - sum of last four layers
# - extraction of the second-to-last layer
#
# Here, for the first pass, I will do sum of the last four layers.

# %%
token_vectors = []
for emb in token_embeddings:
    token_vectors.append(torch.sum(emb[-4:], dim=0))
token_vectors = torch.stack(token_vectors)
token_vectors.shape
# Out:
# torch.Size([37, 768])

# %%
token_vectors2 = torch.sum(token_embeddings[:,-4:,:], dim=1)
token_vectors2.shape
# Out:
# torch.Size([37, 768])

# %%
torch.equal(token_vectors, token_vectors2)
# Out:
# True

# %% [markdown]
# This was a more efficient way!

# %% [markdown]
# Next, we need to go through the tokens and combine those that belong to the same word.

# %%
word_token_lengths = []
for word in tr_stt_words[23]:
    word_token_lengths.append(len(tokenizer.encode(word, add_special_tokens=False)))

# %%
id = 0
word_vectors = []
for wl in word_token_lengths:
    word_vectors.append(torch.mean(token_vectors[id:id+wl], dim=0))
    id = id+wl
word_vectors = torch.stack(word_vectors)

# %%
final_vectors.shape
# Out:
# torch.Size([36, 768])

# %%
len(tr_stt_words[23])
# Out:
# 36

# %%
type(final_vectors)
# Out:
# torch.Tensor

# %% [markdown]
# I strongly beleive this works. If anyone has any idea why it might not, feel free to share.

# %% [markdown]
# Let's test the implementation:

# %%
from bert_encoder import encode_sentence

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model_bert = BertModel.from_pretrained('bert-base-uncased', output_hidden_states=True)
model_bert.eval();

# %%
sentence = ''
words = []

vectors = encode_sentence(sentence, words, model_bert, tokenizer)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[220], line 4
#       1 sentence = ''
#       2 words = []
# ----> 4 vectors = encode_sentence(sentence, words, model_bert, tokenizer)
#
# File ~/EPFL/SEMESTAR_1/ML/ml-project-2-machinesoflearning/DUSAN/../bert_encoder.py:82, in encode_sentence(sentence, words, model, tokenizer, vectorization)
#      79     word_vectors.append(torch.mean(token_vectors[tid : tid + wl], dim=0))
#      80     tid = tid + wl
# ---> 82 return torch.stack(word_vectors)
#
# RuntimeError: stack expects a non-empty TensorList

# %%
torch.equal(final_vectors, vectors)
# Out:
# True

# %%
vectors = encode_sentence(sentence, words, model_bert, tokenizer, vectorization='concat')

# %%
vectors = encode_sentence(sentence, words, model_bert, tokenizer, vectorization='stl')

# %% [markdown]
# Let's do the whole corpus:

# %%
tr_stt_words
# Out:
# (['of',
#   'my',
#   'too',
#   'on',
#   'the',
#   'yellow',
#   'regal',
#   'are',
#   'green',
#   'acts',
#   'so',
#   'things'],
#  ['she',
#   'has',
#   'blond',
#   'or',
#   'brown',
#   'hair',
#   'he',
#   'is',
#   'wearing',
#   'a',
#   'green',
#   'shirt'],
#  ['interested', 'how', 'big', 'are', 'you'],
#  ['ok'],
#  ['thank', 'you'],
#  ['if',
#   'you',
#   'had',
#   'a',
#   'ticket',
#   'to',
#   'go',
#   'somewhere',
#   'where',
#   'wild',
#   'you',
#   'go',
#   'or',
#   'this',
#   'hard',
#   'questions',
#   'i',
#   'would',
#   'go',
#   'through',
#   'a',
#   'very',
#   'to',
#   'dubai',
#   'and',
#   'i',
#   'will',
#   'leave',
#   'dort',
#   'because',
#   'it',
#   'is',
#   'beautiful',
#   'it',
#   'is',
#   'a',
#   'beautiful',
#   'land',
#   'and',
#   'it',
#   'is',
#   'arabic',
#   'like',
#   'me',
#   'yea',
#   'and',
#   'you'],
#  ['yea', 'and', 'both', 'of', 'the', 'child', 'has', 'brown', 'hair'],
#  ['my',
#   'best',
#   'friend',
#   'i',
#   'have',
#   'a',
#   'couple',
#   'of',
#   'them',
#   'and',
#   'be',
#   'different',
#   'between',
#   'a',
#   'good',
#   'friend',
#   'and',
#   'the',
#   'best',
#   'friend',
#   'is',
#   'like',
#   'if',
#   'you',
#   'fall',
#   'down',
#   'a',
#   'good',
#   'friend',
#   'will',
#   'say',
#   'are',
#   'you',
#   'okay',
#   'can',
#   'i',
#   'help',
#   'you',
#   'and',
#   'a',
#   'best',
#   'friend',
#   'is',
#   'like',
#   'they',
#   'laugh',
#   'and',
#   'you',
#   'love',
#   'because',
#   'they',
#   'will',
#   'before',
#   'they',
#   'help',
#   'you',
#   'they',
#   'laugh',
#   'at',
#   'that',
#   'you',
#   'love',
#   'and',
#   'that',
#   'that',
#   'gives',
#   'you',
#   'gives',
#   'you',
#   'like',
#   'a',
#   'good',
#   'feeling'],
#  ['orbit',
#   'eat',
#   'is',
#   'a',
#   'tomato',
#   'soup',
#   'my',
#   'husk',
#   'is',
#   'lesage',
#   'because',
#   'its',
#   'lasai',
#   'mid',
#   'kise',
#   'my',
#   'fur',
#   'big',
#   'spot',
#   'is',
#   'swimming',
#   'i',
#   'can',
#   'we',
#   'good',
#   'swimming',
#   'or',
#   'by',
#   'living',
#   'animal',
#   'is',
#   'nails'],
#  ['yes'],
#  ['how', 'many', 'balls', 'do', 'you', 'have', 'in', 'the', 'picture'],
#  ['i', 'could', 'sleep', 'fitch', 'modeled', 'folkes'],
#  ['its', 'animal', 'sells', 'animal', 'heath', 'meat', 'press'],
#  ['describe',
#   'your',
#   'family',
#   'my',
#   'family',
#   'i',
#   'have',
#   'a',
#   'mother',
#   'a',
#   'father',
#   'a',
#   'big',
#   'sister',
#   'and',
#   'a',
#   'little',
#   'brother',
#   'i',
#   'have',
#   'one',
#   'big',
#   'kusa',
#   'and',
#   '2',
#   'little',
#   'cousins',
#   'i',
#   'have',
#   'one',
#   'grandfather',
#   'that',
#   'he',
#   'dies',
#   'and',
#   'the',
#   'other',
#   'is',
#   'on',
#   'live',
#   'i',
#   'have',
#   '2',
#   'grandmothers',
#   'both',
#   'are',
#   'on',
#   'live',
#   'i',
#   'have',
#   'one',
#   'i',
#   'have',
#   '3',
#   'uncles',
#   'and',
#   'now',
#   '5',
#   'uncles',
#   'but',
#   '2',
#   'or',
#   'die',
#   'yes',
#   'and',
#   'i',
#   'have',
#   'oko',
#   'elton',
#   'and',
#   'they',
#   'are',
#   'on',
#   'life',
#   'and',
#   'you'],
#  ['yet', 'its', 'coffee'],
#  ['3'],
#  ['i', 'live', 'in', 'a', 'sea'],
#  ['my',
#   'best',
#   'friend',
#   'is',
#   'tomato',
#   'and',
#   'she',
#   'is',
#   'house',
#   'is',
#   'of',
#   'tomato',
#   'and',
#   'a',
#   'potato',
#   'and',
#   'in',
#   'my',
#   'city',
#   'have',
#   'more',
#   'field',
#   'potatoes',
#   'have',
#   'out',
#   'under',
#   'a',
#   'retched',
#   'tavice'],
#  ['yes'],
#  ['okay',
#   'it',
#   'tell',
#   'me',
#   'about',
#   'your',
#   'ferried',
#   'thing',
#   'to',
#   'do',
#   'in',
#   'a',
#   'word'],
#  ['issue', 'a', 'colored', 'man'],
#  ['this',
#   'open',
#   'the',
#   'try',
#   'if',
#   'i',
#   'want',
#   'to',
#   'check',
#   'some',
#   'thing'],
#  ['i',
#   'would',
#   'choose',
#   'also',
#   'the',
#   'beach',
#   'because',
#   'i',
#   'do',
#   'not',
#   'know',
#   'what',
#   'to',
#   'do',
#   'with',
#   'a',
#   'bush'],
#  ['i',
#   'can',
#   'see',
#   'our',
#   'anon',
#   'picture',
#   'red',
#   'grass',
#   'or',
#   'sand',
#   'and',
#   'sun',
#   'yellow',
#   'and',
#   'blue',
#   'sky',
#   'and',
#   'a',
#   'other',
#   'round',
#   'picture',
#   'i',
#   'can',
#   'see',
#   'the',
#   'sky',
#   'is',
#   'yellow',
#   'and',
#   'underground',
#   'are',
#   'pink',
#   'violet',
#   'and',
#   'hell',
#   'brown'],
#  ['not', 'the', 'mouse'],
#  ['and', 'one', 'is', 'is', 'it', 'is', 'made', 'of', 'wood'],
#  ['p', '0'],
#  ['it', 'is', 'a', 'umbrella'],
#  ['yes'],
#  ['sun', 'glasses', 'it', 'is', 'ruined', 'there', 'are', '12', 'numbers'],
#  ['here'],
#  ['do',
#   'you',
#   'have',
#   'a',
#   'photo',
#   'of',
#   'the',
#   'grass',
#   'and',
#   'the',
#   'sun'],
#  ['i', 'see', 'a', 'rose'],
#  ['is', 'a', 'feather', 'but'],
#  ['metis'],
#  ['yes'],
#  ['i',
#   'like',
#   'to',
#   'play',
#   'floor',
#   'around',
#   'than',
#   'all',
#   'of',
#   'my',
#   'family',
#   'playing',
#   'floorball',
#   'and',
#   'i',
#   'also',
#   'playing',
#   'floriva',
#   'and',
#   'i',
#   'likes',
#   'and',
#   'i',
#   'have',
#   'a',
#   'good',
#   'team',
#   'we',
#   'are',
#   'in',
#   'the',
#   'switzerland',
#   'mastershofts',
#   'and',
#   'then',
#   'we',
#   'got',
#   'the',
#   '9',
#   'place'],
#  ['yes'],
#  ['the', 'beach', 'tell', 'me', 'the', 'funniest', 'joke', 'you', 'know'],
#  ['geser', 'and', 'blank'],
#  ['have', 'to', 'buy', 'a', 'blue', 'queen', 'turcus', 'jacket'],
#  ['yes',
#   'it',
#   'is',
#   'an',
#   'animal',
#   'you',
#   'can',
#   'you',
#   'can',
#   'make',
#   'sport',
#   'with'],
#  ['in',
#   'the',
#   'library',
#   'there',
#   'are',
#   'lots',
#   'of',
#   'people',
#   'there',
#   'is',
#   'very',
#   'old',
#   'people',
#   'and',
#   'very',
#   'young',
#   'people',
#   'are',
#   'is',
#   'a',
#   'cat',
#   'on',
#   'the',
#   'stars',
#   'and',
#   'it',
#   'has',
#   'a',
#   'woman',
#   'with',
#   'pink',
#   'hair',
#   'there',
#   'are',
#   '3',
#   'dogs',
#   'before',
#   'the',
#   'library',
#   'there',
#   'are',
#   '5',
#   'jackets',
#   'on',
#   'no',
#   'jacket',
#   'hold',
#   'it',
#   'is',
#   'a',
#   'woman',
#   'with',
#   'a',
#   'fish',
#   'back',
#   'he',
#   'reading',
#   'in',
#   'a',
#   'book',
#   'our',
#   'fish',
#   'a',
#   'very',
#   'young',
#   'boy',
#   'are',
#   'reading',
#   'in',
#   'a',
#   'book',
#   'with',
#   'a',
#   'lion',
#   'there',
#   'also',
#   'an',
#   'old',
#   'woman',
#   'the',
#   'on',
#   'their',
#   'sitting',
#   'honor',
#   'chin',
#   'and',
#   'kids',
#   'a',
#   'woman',
#   'reading',
#   'the',
#   'kids',
#   'fall',
#   'he',
#   'has',
#   'he',
#   'our',
#   'parents',
#   'with',
#   'kids',
#   'and',
#   'it',
#   'is',
#   'in',
#   'the',
#   'library',
#   'i',
#   'can',
#   'see',
#   'a',
#   'sofa',
#   'with',
#   'lots',
#   'of',
#   'people',
#   'that',
#   'are',
#   'reading',
#   'in',
#   'books',
#   'in',
#   'in',
#   'on',
#   'sizes',
#   'there',
#   'is',
#   'a',
#   'computer',
#   'with',
#   '2',
#   'kids',
#   'men',
#   'with',
#   'wcuootetonkid',
#   'on',
#   'kid',
#   'is',
#   'books',
#   'kids',
#   'book',
#   'bogs',
#   'are',
#   'pippylangstroom',
#   'an',
#   'old',
#   'woman',
#   'bitzalt',
#   'imfuthere',
#   'are',
#   'very',
#   'old',
#   'man',
#   'harry',
#   'patcher',
#   'is',
#   'also',
#   'in',
#   'the',
#   'library',
#   'in',
#   'one',
#   'on',
#   'a',
#   'sit',
#   'ssuck',
#   'or',
#   'a',
#   'girl',
#   'with',
#   'white',
#   'hair',
#   'there',
#   'are',
#   'lots',
#   'of',
#   'bags',
#   'and',
#   'jackets',
#   'there',
#   'are',
#   'shoes',
#   'before',
#   'the',
#   'cosset',
#   'there',
#   'are',
#   'lots',
#   'of',
#   'books',
#   'in',
#   'the',
#   'arms',
#   'for',
#   'a',
#   'little',
#   'girl',
#   'one',
#   'model',
#   'with',
#   'his',
#   'daughter',
#   'they',
#   'are',
#   'reading',
#   'in',
#   'a',
#   'book'],
#  ['a', 'boss'],
#  ['yes'],
#  ['are', 'you', 'playing', 'handball'],
#  ['would',
#   'you',
#   'rather',
#   'be',
#   'able',
#   'to',
#   'fly',
#   'or',
#   'to',
#   'be',
#   'invisible'],
#  ['and', 'television'],
#  ['yes', 'and', 'on', 'the', 'right', 'side', 'is', 'a', 'red'],
#  ['it',
#   'has',
#   'called',
#   'you',
#   'can',
#   'do',
#   'it',
#   'with',
#   'meat',
#   'or',
#   'vertical',
#   'it',
#   'has',
#   'tees',
#   'and',
#   'bread',
#   'watches',
#   'it'],
#  ['okay',
#   'that',
#   'is',
#   'so',
#   'crad',
#   'i',
#   'am',
#   'going',
#   'to',
#   'school',
#   'in',
#   'comic',
#   'housing',
#   'street'],
#  ['so',
#   'you',
#   'know',
#   'i',
#   'can',
#   'do',
#   'both',
#   'of',
#   'them',
#   'all',
#   'right',
#   'but',
#   'now',
#   'now',
#   'is',
#   'not',
#   'a',
#   'stump',
#   'growing',
#   'but',
#   'i',
#   'would',
#   'rather',
#   'do',
#   'fly',
#   'because',
#   'invisible',
#   'it',
#   'is',
#   'cool',
#   'but',
#   'it',
#   'is',
#   'i',
#   'think',
#   'flying',
#   'is',
#   'peters',
#   'feels',
#   'cooler',
#   'when',
#   'you',
#   'fly',
#   'in',
#   'the',
#   'air',
#   'so',
#   'popi',
#   'tell',
#   'me',
#   'about',
#   'something',
#   'that',
#   'you',
#   'love'],
#  ['and',
#   'the',
#   'cat',
#   'at',
#   'the',
#   'sofa',
#   'you',
#   'have',
#   'hell',
#   'brown',
#   'and',
#   'on',
#   'the',
#   'other',
#   'picture',
#   'gray',
#   'white'],
#  ['yes', 'do', 'you', 'drawing'],
#  ['my', 'david', 'book', 'lotli'],
#  ['yes'],
#  ['nucs', 'i', 'do', 'not', 'have', 'i', 'ave', 'putting'],
#  ['it', 'is', 'a', 'fish'],
#  ['the', 'core'],
#  ['it', 'was', 'a', 'cat'],
#  ['and', 'i', 'am', 'one'],
#  ['lo', 'i', 'name', 'is', 'picacho'],
#  ['a', 'book'],
#  ['i',
#   'have',
#   'or',
#   '2',
#   'pictures',
#   '2',
#   'cats',
#   'in',
#   'my',
#   'picture',
#   'and',
#   'the',
#   'iron',
#   'is',
#   'gray',
#   'and',
#   'the',
#   'other',
#   'one',
#   'is',
#   'white'],
#  ['i',
#   'can',
#   'see',
#   'in',
#   'the',
#   'picture',
#   'a',
#   'boy',
#   'with',
#   'a',
#   'very',
#   'big',
#   'and',
#   'dark',
#   'and',
#   'the',
#   'boy',
#   'have',
#   'a',
#   'skateboard',
#   'and',
#   'she',
#   'is',
#   'skating',
#   'she',
#   'had',
#   'so',
#   'can',
#   'not',
#   'we',
#   'start',
#   'it',
#   'is',
#   'not',
#   'and',
#   'i',
#   'can',
#   'see',
#   'in',
#   'the',
#   'picture',
#   'a',
#   'boy',
#   'with',
#   'a',
#   'very',
#   'big',
#   'dog',
#   'and',
#   'i',
#   'can',
#   'see',
#   'a',
#   'motor',
#   'with',
#   'a',
#   'very',
#   'small',
#   'dog',
#   'and',
#   'very',
#   'much',
#   'people',
#   'playing',
#   'football',
#   'and',
#   'i',
#   'can',
#   'see',
#   'the',
#   'trainer',
#   'with',
#   'a',
#   'very',
#   'big',
#   'dog',
#   'and',
#   'i',
#   'can',
#   'see',
#   'the',
#   'golie',
#   'have',
#   'a',
#   'blue',
#   'trickle',
#   'and',
#   'i',
#   'can',
#   'see',
#   'the',
#   'trenner',
#   'she',
#   'has',
#   'an',
#   'orange',
#   'the',
#   'shirt',
#   'and',
#   'a',
#   'blue',
#   'cap',
#   'and',
#   'a',
#   'black',
#   'and',
#   'a',
#   'black',
#   'bag',
#   'and',
#   'i',
#   'can',
#   'see',
#   'a',
#   'boy',
#   'with',
#   '5',
#   'balls',
#   'a'],
#  ['yes'],
#  ['are', 'you', 'eating', 'a', 'sandwich'],
#  ['the', 'snake'],
#  ['tell', 'me', 'funny', 'choke', 'you', 'now'],
#  ['ah', 'what', 'is', 'your', 'favorite', 'pudding'],
#  ['your', 'tickings', 'killing', 'cates'],
#  ['does', 'she', 'have', 'a', 'hat'],
#  ['yes', 'i', 'am', 'standing'],
#  ['i', 'need', 'donats', 'do', 'you', 'have', 'donats'],
#  ['yes', 'it', 'is', 'a', 'train'],
#  ['i',
#   'wish',
#   'that',
#   'the',
#   'planet',
#   'go',
#   'on',
#   'the',
#   'planet',
#   'is',
#   'better',
#   'them',
#   'now',
#   'so',
#   'that',
#   'there',
#   'are',
#   'more',
#   'animals',
#   'and',
#   'more',
#   'forests'],
#  ['me', 'tong', 'because', 'it', 'is', 'funny'],
#  ['i', 'can'],
#  ['yes', 'please'],
#  ['no'],
#  ['no', 'i', 'want', 'to', 'buy', 'some', 'muffin'],
#  ['yes'],
#  ['based', 'shet'],
#  ['he', 'pen'],
#  ['is', 'the', 'girl', 'on', 'the', 'round'],
#  ['2', 'toffies'],
#  ['cash', 'please', 'thank', 'you'],
#  ['yes'],
#  ['it',
#   'is',
#   'small',
#   'it',
#   'has',
#   'a',
#   'body',
#   'it',
#   'can',
#   'swim',
#   'it',
#   'lives',
#   'in',
#   'the',
#   'water',
#   'what',
#   'is',
#   'it'],
#  ['yes'],
#  ['in',
#   'the',
#   'holidays',
#   'i',
#   'like',
#   'to',
#   'go',
#   'out',
#   'with',
#   'my',
#   'family',
#   'eat',
#   'ice',
#   'cream',
#   'or',
#   'play',
#   'with',
#   'my',
#   'friends'],
#  ['it', 'is', 'a', 'tree'],
#  ['in',
#   'my',
#   'picture',
#   'there',
#   'is',
#   'also',
#   'a',
#   'flying',
#   'ball',
#   'that',
#   'not',
#   'in',
#   'the',
#   'gall'],
#  ['no', 'are', 'you', 'ever', 'a', 'whale'],
#  ['i', 'like', 'to', 'drawing', 'and', 'do', 'gymnastic'],
#  ['you', 'make', 'your', 'food', 'there'],
#  ['how', 'many', 'colors', 'does', 'your', 'son', 'have'],
#  ['this', 'woman'],
#  ['yes'],
#  ['it', 'is', 'summer'],
#  ['fruits', 'a'],
#  ['it', 'is', 'a', 'class', 'room'],
#  ['peso'],
#  ['yes', 'are', 'you', 'kicking'],
#  ['so', 'do', 'you', 'have', 'a', 'friend', 'that', 'i', 'now'],
#  ['this',
#   'is',
#   'the',
#   'basis',
#   'and',
#   'get',
#   'that',
#   'men',
#   'gris',
#   'it',
#   'this',
#   'boy'],
#  ['you', 'have', 'purple', 'trees', 'a', 'to'],
#  ['my', 'favorite', 'pet', 'is', 'a', 'turtle'],
#  ['i',
#   'can',
#   'see',
#   '2',
#   'typin',
#   'in',
#   'ways',
#   'and',
#   'the',
#   'tulpen',
#   'is',
#   'orange',
#   'red'],
#  ['one', 'room', 'it', 'is', 'rare'],
#  ['i', 'am', 'fluke', 'choke', 'yes'],
#  ['it', 'is', 'the', 'animal'],
#  ['hi', 'my', 'name', 'is', 'pocahontas'],
#  ['trigger'],
#  ['okay', 'i', 'can', 'see', 'a', 'yellow', 'flower'],
#  ['and', 'there', 'are', 'a', 'throne'],
#  ['yourself'],
#  ['it', 'and', 'car'],
#  ['yes'],
#  ['i', 'have', 'the', 'girl', 'brown', 'hair'],
#  ['yes'],
#  ['hello'],
#  ['no'],
#  ['if',
#   'you',
#   'could',
#   'have',
#   'a',
#   'patios',
#   'what',
#   'would',
#   'you',
#   'do',
#   'with',
#   'it'],
#  ['in',
#   'upon',
#   'well',
#   'it',
#   'is',
#   'very',
#   'nice',
#   'and',
#   'cool',
#   'and',
#   'warm'],
#  ['i',
#   'can',
#   'also',
#   'see',
#   'a',
#   'couch',
#   'have',
#   'you',
#   'on',
#   'the',
#   'couch',
#   'a',
#   'purple',
#   'inanimate',
#   'kissen'],
#  ['easily', 'a', 'dog', 'because', 'they', 'are', 'cumilar', 'than', 'cats'],
#  ['i',
#   'would',
#   'take',
#   'a',
#   'cab',
#   'my',
#   'smartphone',
#   'maybe',
#   'a',
#   'pole',
#   'and',
#   'cider',
#   'and',
#   'the',
#   'weland',
#   'book',
#   'says',
#   'my',
#   'friend',
#   'thee'],
#  ['it', 'is', 'a', 'house'],
#  ['okay', 'sun', 'or', 'walter', 'park'],
#  ['banana'],
#  ['i', 'do', 'not', 'know', 'beach', '0', 'mountains'],
#  ['dammed', 'bear', 'was', 'left', 'have', 'blue', 'and', 'pink', 'muzzer'],
#  ['i',
#   'can',
#   'see',
#   'a',
#   'girl',
#   'with',
#   'a',
#   'pink',
#   'dress',
#   'and',
#   'purple',
#   't',
#   'shirt'],
#  ['yes', 'i', 'days'],
#  ['when', 'were', 'you', 'the', 'happiest'],
#  ['are', 'you', 'playing', 'in', 'a', 'club'],
#  ['yet'],
#  ['hi', 'what', 'is', 'your', 'name'],
#  ['i',
#   'was',
#   'in',
#   'africa',
#   'unsaffairy',
#   'and',
#   'and',
#   'there',
#   'were',
#   'a',
#   'lot',
#   'of',
#   'animals',
#   'and',
#   'unlike',
#   'animals',
#   'very',
#   'much',
#   'and'],
#  ['note', 'and', 'hinders', 'a', 'clod'],
#  ['yes'],
#  ['is', 'dog'],
#  ['at', 'a', 'clock'],
#  ['we', 'will', 'see', 'a', 'game'],
#  ['i', 'will', 'run', 'vachon', 'per'],
#  ['as', 'i', 'like', 'to', 'fly', 'what', 'is', 'about', 'you'],
#  ['it',
#   'is',
#   'small',
#   'it',
#   'was',
#   'very',
#   'hot',
#   'and',
#   'it',
#   'was',
#   'pink',
#   'it',
#   'was',
#   'also',
#   'candid',
#   'give',
#   'and',
#   'colorful'],
#  ['no'],
#  ['no'],
#  ['good', 'nice', 'nice', 'to', 'meet', 'you', 'i', 'go', 'home'],
#  ['what', 'do', 'you', 'like', 'doing', 'in', 'your', 'free', 'time'],
#  ['i', 'love', 'plorable', 'what', 'about', 'you'],
#  ['pabricacrisps', 'and', 'salty', 'crisps'],
#  ['ye'],
#  ['do', 'you', 'won', 'with', 'a', 'card', 'or', 'tint'],
#  ['yellow', 'can', 'you', 'say', 'me', 'more', 'like', 'us', 'do', 'not'],
#  ['how', 'big', 'is', 'arcot', 'is', 'cake'],
#  ['easily',
#   'summer',
#   'because',
#   'it',
#   'is',
#   'warmer',
#   'and',
#   'you',
#   'can',
#   'go',
#   'swim'],
#  ['the', 'beach'],
#  ['that', 'sounds', 'interesting'],
#  ['7', 'm', 'that', 'was', 'one', 'picture'],
#  ['yes', 'by', 'me'],
#  ['the', 'boy', 'an', 'straw', 'in', 'a', 'circle'],
#  ['hi', 'my', 'name', 'is', 'girl', 'what', 'you', 'name'],
#  ['so',
#   'like',
#   'you',
#   'mean',
#   'what',
#   'i',
#   'like',
#   'under',
#   'some',
#   'feeling',
#   'or'],
#  ['okay',
#   'then',
#   'i',
#   'take',
#   'the',
#   'chocolate',
#   'so',
#   'i',
#   'like',
#   'to',
#   'have',
#   '4',
#   'of',
#   'the',
#   'chocolate',
#   'mutton',
#   'so'],
#  ['it', 'has', 'a', 'trunk'],
#  ['unit'],
#  ['my', 'is', 'yellow', 'and', 'doll'],
#  ['this', 'is', 'queens', 'and', 'has', 'a', 'schne', 'and', 'has', 'a'],
#  ['i',
#   'can',
#   'listen',
#   'in',
#   'this',
#   'thing',
#   'we',
#   'will',
#   'have',
#   'these',
#   'things',
#   'in',
#   'the',
#   'school',
#   'very',
#   'much',
#   'things'],
#  ['okay',
#   'we',
#   'onpoyou',
#   'drink',
#   'it',
#   'in',
#   'the',
#   'morning',
#   'it',
#   'wakes',
#   'you',
#   'up'],
#  ['and', 'terringham'],
#  ['act', '4', 'poses', 'taking', 'a', 'tone', 'as', 'pink', 'glow'],
#  ['arm',
#   'okay',
#   'then',
#   'i',
#   'take',
#   'that',
#   'so',
#   'and',
#   'so',
#   'do',
#   'you',
#   'have',
#   'candy'],
#  ['yes', 'it', 'is', 'a', 'tube'],
#  ['i', 'know', 'hand', 'what', 'do', 'you', 'have', 'for', 'us'],
#  ['black', 'hair'],
#  ['yes', 'the', 'flowers', 'all', 'red'],
#  ['i',
#   'am',
#   'an',
#   'animal',
#   'the',
#   'logic',
#   'i',
#   'love',
#   'animals',
#   'do',
#   'you',
#   'have',
#   'friends',
#   'here'],
#  ['good', 'pard', 'i'],
#  ['yes'],
#  ['here', 'is', 'a', 'apple'],
#  ['uniting', 'bird'],
#  ['okay'],
#  ['i',
#   'do',
#   'not',
#   'know',
#   'i',
#   'love',
#   'all',
#   'things',
#   'if',
#   'you',
#   'could',
#   'have',
#   'any',
#   'animal',
#   'at',
#   'a',
#   'pet',
#   'what',
#   'would',
#   'it',
#   'be'],
#  ['one', 'a'],
#  ['and', 'what', 'hates', 'you'],
#  ['and', 'i', 'see', '2', 'flowers', 'in', 'rat'],
#  ['yes', 'okay', 'smarter', 'and', 'take', 'a', 'cup'],
#  ['yes', 'i', 'am', 'jumping'],
#  ['do', 'you', 'a', 'girl'],
#  ['3'],
#  ['i',
#   'love',
#   'popcon',
#   'as',
#   'i',
#   'said',
#   'and',
#   'watch',
#   'plopping',
#   'it',
#   'but',
#   'i',
#   'hate',
#   'bones',
#   'i',
#   'do',
#   'not',
#   'know',
#   'what',
#   'all',
#   'dogs',
#   'have',
#   'with',
#   'bones',
#   'i',
#   'just',
#   'like',
#   'pop',
#   'con',
#   'what',
#   'do',
#   'you',
#   'off',
#   'and',
#   'hate'],
#  ['i',
#   'am',
#   'from',
#   'i',
#   'live',
#   'in',
#   'a',
#   'village',
#   'in',
#   'switzerland',
#   'what',
#   'about',
#   'you'],
#  ['2'],
#  ['there', 'is', 'a', 'little', 'screen', 'showing', 'abc'],
#  ['tell',
#   'me',
#   'about',
#   'tell',
#   'me',
#   'the',
#   'funniest',
#   'choke',
#   'you',
#   'con'],
#  ['we', 'can', 'eat', 'at', 'a', 'macdonald', 'and', 'like', 'that'],
#  ['it', 'is', 'tray'],
#  ['i'],
#  ['where', 'are', 'you', 'from'],
#  ['no'],
#  ['i',
#   'love',
#   'my',
#   'hamster',
#   'lumi',
#   'and',
#   'my',
#   'family',
#   'and',
#   'my',
#   'friends',
#   'i',
#   'love',
#   'my',
#   'dog',
#   'chine',
#   'and',
#   'my',
#   'brother',
#   'nebo',
#   'it',
#   'is',
#   'in',
#   'the',
#   'same',
#   'class',
#   'they',
#   'am',
#   'i',
#   'and',
#   'my',
#   'family',
#   'my',
#   'mother',
#   'and',
#   'my',
#   'father',
#   'yeh',
#   'fruit',
#   'are',
#   'wedged',
#   'in',
#   'bulls'],
#  ['is', 'it', 'a', 'clock'],
#  ['chocklets'],
#  ['and', 'yes'],
#  ['is',
#   'round',
#   'and',
#   'in',
#   'the',
#   'simmer',
#   'and',
#   'have',
#   'a',
#   'long',
#   'stripe',
#   'and',
#   'small',
#   'stripe',
#   'and',
#   'one',
#   'middle',
#   'stripe'],
#  ['i',
#   'cannot',
#   'seep',
#   'plancon',
#   'but',
#   'it',
#   'is',
#   'at',
#   'the',
#   'left',
#   'side'],
#  ['not'],
#  ['it', 'is', 'a', 'monkey'],
#  ['yes', 'this', 'girl'],
#  ['why', 'do', 'you', 'want', 'to', 'be', 'a', 'foot'],
#  ['no'],
#  ['yes'],
#  ['setting', 'and', 'sleeping'],
#  ['pancks',
#   'yes',
#   'i',
#   'have',
#   'got',
#   'pancks',
#   'till',
#   'i',
#   'how',
#   'many',
#   'should',
#   'i',
#   'bring',
#   'you'],
#  ['yes'],
#  ['i', 'can', 'not', 'see', 'a', 'boy', 'she', 'has', 'a', 'blue', 'hair'],
#  ['it',
#   'is',
#   'she',
#   'can',
#   'work',
#   'it',
#   'has',
#   'to',
#   'eyes',
#   'and',
#   '2',
#   'ears',
#   'it',
#   'can',
#   'can'],
#  ['i',
#   'prefer',
#   'pirates',
#   'would',
#   'you',
#   'rather',
#   'be',
#   'a',
#   'cat',
#   'or',
#   'a',
#   'dog',
#   'for',
#   'an',
#   'entire',
#   'day'],
#  ['blue', 'that', 'is', 'a', 'different'],
#  ['yes'],
#  ['yes'],
#  ['winter', 'or', 'summer'],
#  ['i', 'have', 'eaten', 'lines'],
#  ['would',
#   'you',
#   'rather',
#   'be',
#   'a',
#   'dog',
#   'for',
#   'a',
#   'day',
#   'or',
#   'a',
#   'cat',
#   'for',
#   'a',
#   'day'],
#  ['and', 'an', 'auto'],
#  ['i', 'can', 'bake'],
#  ['i', 'am', '10', 'years', 'old', 'when', 'is', 'your', 'birthday'],
#  ['tell',
#   'me',
#   'about',
#   'your',
#   'favorite',
#   'book',
#   'my',
#   'favorite',
#   'book',
#   'is',
#   'sure',
#   'demotion',
#   'here',
#   'because',
#   'it',
#   'is',
#   'really',
#   'cool',
#   'when',
#   'you',
#   'read',
#   'you',
#   'do',
#   'not',
#   'want',
#   'to',
#   'go',
#   'a',
#   'sleep',
#   'or',
#   'you',
#   'do',
#   'not',
#   'want',
#   'to',
#   'go',
#   'like',
#   'eating',
#   'because',
#   'in',
#   'the',
#   'book',
#   'is',
#   'stuck',
#   'in',
#   'the',
#   'book',
#   'and',
#   'it',
#   'is',
#   'very',
#   'such',
#   'a',
#   'cool',
#   'book',
#   'you',
#   'old',
#   'water',
#   'like',
#   'we',
#   'moved',
#   'them',
#   'here',
#   'and',
#   'are',
#   'now',
#   'by',
#   'number',
#   '5',
#   'and',
#   'defer',
#   'it',
#   'is',
#   'named',
#   'penny',
#   'in',
#   'envite',
#   'in',
#   'there',
#   'with',
#   'uncle',
#   'in',
#   'germany',
#   'he',
#   'lives',
#   'in',
#   'germany',
#   'and',
#   'they',
#   'are',
#   'at',
#   'camping',
#   'ike',
#   'a',
#   'place',
#   'with',
#   'camping',
#   'over',
#   'the',
#   'camp',
#   'arab',
#   'but',
#   'would',
#   'camping'],
#  ['and', '3', 'pete', 'this', 'm', 'chiet'],
#  ['it',
#   'is',
#   'a',
#   'belchium',
#   'and',
#   'i',
#   'looking',
#   'of',
#   'this',
#   'and',
#   'i',
#   'laughing'],
#  ['i',
#   'can',
#   'see',
#   'a',
#   'little',
#   'i',
#   'can',
#   'see',
#   'a',
#   'little',
#   'a',
#   'little',
#   'dog',
#   'and',
#   'he',
#   'is',
#   'running',
#   'into',
#   'supermarket',
#   'and',
#   'i',
#   'can',
#   'see',
#   'i',
#   'can',
#   'see',
#   'pizzas',
#   'and',
#   'i',
#   'can',
#   'see',
#   'out',
#   'chips',
#   'and',
#   'i',
#   'can',
#   'see',
#   'girls',
#   'and',
#   'i',
#   'can',
#   'see',
#   'brats',
#   'and',
#   'cheese',
#   'and',
#   'i',
#   'can',
#   'see',
#   'fish',
#   'and',
#   'a',
#   'and',
#   'b',
#   'and',
#   's',
#   'c',
#   'and',
#   'i',
#   'can',
#   'see',
#   '3',
#   'and',
#   'at',
#   '2',
#   'and',
#   'i',
#   'can',
#   'see',
#   'ice',
#   'cream',
#   'and',
#   'a',
#   'car',
#   'and',
#   'i',
#   'can',
#   'see',
#   'red',
#   'globe',
#   'round',
#   'robe',
#   'a',
#   'big',
#   'round',
#   'platter',
#   'a',
#   'girl',
#   'with',
#   'mam',
#   'and',
#   'end',
#   '2',
#   'play',
#   'and',
#   'smoothes',
#   'and',
#   'i',
#   'can',
#   'see',
#   'milk',
#   'and',
#   'i',
#   'can',
#   'seated',
#   'in',
#   'what',
#   'now',
#   'and',
#   'at',
#   'that',
#   'archongliren',
#   'i',
#   'can',
#   'see',
#   'a',
#   'bondi',
#   'can',
#   'see',
#   'a',
#   'girl',
#   'there',
#   'are',
#   'lots',
#   'of',
#   'pizzas',
#   'in',
#   'the',
#   'hand',
#   'and',
#   'i',
#   'can',
#   'see',
#   '4',
#   'girls',
#   'they',
#   'are',
#   'looking',
#   'ex'],
#  ['what', 'i', 'am', 'doing'],
#  ['cake', 'yes', 'we', 'have', 'a', 'chocolate', 'and', 'berry'],
#  ['i', 'can', 'see', 'a', 'girl', 'with', 'brown', 'hears'],
#  ['mine', 'is', '25', 'of', 'december', '25th', 'of', 'december'],
#  ['good', 'there', 'would', 'be', '25', 'bucks'],
#  ['i', 'come', 'from', 'a', 'hole'],
#  ['in',
#   'an',
#   'when',
#   'you',
#   'fall',
#   'down',
#   'or',
#   'you',
#   'have',
#   'a',
#   'home',
#   'fall',
#   'you',
#   'can',
#   'then',
#   'come',
#   'this',
#   'core',
#   'and',
#   'get',
#   'up'],
#  ['i',
#   'do',
#   'not',
#   'see',
#   'a',
#   'yellow',
#   'flower',
#   'but',
#   'i',
#   'see',
#   'a',
#   'orange',
#   'flower'],
#  ['now', 'it', 'is', 'not'],
#  ['a', 'beanfeasts', 'highest'],
#  ['to', 'me', 'has', '4', 'kisses'],
#  ['what', 'am', 'i', 'to', 'win'],
#  ['yes', 'i', 'must', 'skip', 'a', 'poet', 'tions', 'and', 'easton'],
#  ['no'],
#  ['and',
#   'would',
#   'you',
#   're',
#   'richer',
#   'be',
#   'a',
#   'dog',
#   'for',
#   'a',
#   'day',
#   'or',
#   'a',
#   'cat',
#   'for',
#   'a',
#   'day'],
#  ['yes', 'the', 'son', 'the', 'mice'],
#  ['the', 'unit', 'is', 'to', 'look', 'around', 'and', 'see', 'the', 'world'],
#  ['yes', 'that', 'is', 'too', 'correct'],
#  ['does', 'she', 'have', 'glasses'],
#  ['it', 'is', 'a', 'supermarket'],
#  ['a', 'discrete', 'your', 'family'],
#  ['or', 'a', 'dispersan'],
#  ['it', 'is', 'in', 'this', 'side'],
#  ['condones'],
#  ['yet'],
#  ['boat'],
#  ['god', 'that', 'she', 'is', 'you', 'will', 'have', 'christ'],
#  ['fal', 'salts'],
#  ['ice', 'cream'],
#  ['it',
#   'is',
#   'big',
#   'it',
#   'has',
#   'strings',
#   'it',
#   'can',
#   'do',
#   'music',
#   'it',
#   '18',
#   'it',
#   'does',
#   'a',
#   'lot',
#   'of',
#   'sound',
#   'what',
#   'is',
#   'it'],
#  ['then',
#   'do',
#   'you',
#   'have',
#   'some',
#   'donats',
#   'like',
#   'a',
#   'chaplet',
#   'may',
#   'be'],
#  ['parents'],
#  ['is', 'a', 'pink', 'rose'],
#  ['abacus', 'sarce'],
#  ['it',
#   'is',
#   'a',
#   'food',
#   'it',
#   'is',
#   'a',
#   'fast',
#   'food',
#   'anon',
#   'mcdonald',
#   'i',
#   'biders'],
#  ['stranding'],
#  ['of', 'time'],
#  ['yes'],
#  ['it', 'is', 'a', 'monkey'],
#  ['does', 'she', 'have', 'a', 'dress'],
#  ['it', 'could', 'be', 'a', 'hot', 'chocolate', 'h'],
#  ['what', 'is', 'this', 'it', 'is', 'a', 'fife', 'yes'],
#  ['and', 'does', 'you', 'have', 'like', 'kepi'],
#  ['thank', 'you'],
#  ['i', 'have', 'come', 'from', 'syrian'],
#  ['have', 'you', 'peanut', 'butter'],
#  ['has', 'he', 'a', 'red', 'white', 'tshirt'],
#  ['a', '3'],
#  ['what', 'is', 'your', 'hobby'],
#  ['tell', 'me', 'about', 'your', 'favorite', 'tv', 'show'],
#  ['what', 'i', 'am', 'doing'],
#  ['i', 'love', 'sunny', 'days', 'and', 'i', 'have', 'tests'],
#  ['yes'],
#  ['i', 'live', 'in', 'a', 'villa', 'in', 'australia'],
#  ['in',
#   'the',
#   'holy',
#   'days',
#   'i',
#   'like',
#   'to',
#   'go',
#   'to',
#   'japan',
#   'because',
#   'i',
#   'like',
#   'sushi',
#   'and',
#   'these',
#   'cherry',
#   'trees'],
#  ['is', 'not', 'an', 'umbrella', 'i', 'said', 'umbrella'],
#  ['okay', 'and', 'nach', 'was'],
#  ['say'],
#  ['you', 'read', 'a', 'message'],
#  ['my',
#   'favorite',
#   'food',
#   'is',
#   'ant',
#   'and',
#   'what',
#   'is',
#   'your',
#   'favorite',
#   'food'],
#  ['no', 'are', 'you', 'this', 'person'],
#  ['is', 'she', 'this', 'person'],
#  ['what', 'is', 'you', 'favorite', 'food'],
#  ['a',
#   'low',
#   'may',
#   'be',
#   'a',
#   'flamingo',
#   'because',
#   'it',
#   'is',
#   'prole',
#   'so',
#   'in',
#   'plots'],
#  ['okay', 'do', 'you', 'have', 'cheering', 'gun'],
#  ['she', 'is', 'big'],
#  ['guess', 'it', 'is'],
#  ['sook'],
#  ['i',
#   'like',
#   'to',
#   'play',
#   'kuno',
#   'because',
#   'i',
#   'like',
#   'to',
#   'play',
#   'card',
#   'games'],
#  ['it', 'is', 'swimming'],
#  ['i',
#   'do',
#   'not',
#   'like',
#   'just',
#   'dance',
#   'in',
#   'this',
#   'thing',
#   'to',
#   'look',
#   'at',
#   'venta'],
#  ['of', 'all'],
#  ['a',
#   'favorite',
#   'feel',
#   'in',
#   'sport',
#   'is',
#   'it',
#   'allegan',
#   'alley',
#   'and',
#   'football'],
#  ['5', 'yeah', 'and', 'please', 'me'],
#  ['i',
#   'can',
#   'not',
#   'see',
#   'the',
#   'world',
#   'but',
#   'i',
#   'can',
#   'not',
#   'see',
#   'one',
#   'country'],
#  ['it',
#   'is',
#   'sometimes',
#   'black',
#   'it',
#   'can',
#   'scratch',
#   'very',
#   'hard',
#   'and',
#   'it',
#   'can',
#   'jump',
#   'from',
#   'high',
#   'places'],
#  ['yes', 'it', 'is', 'a', 'hat'],
#  ['it', 'is', 'the', 'right', 'l'],
#  ['do', 'you', 'have', 'a', 'cake', 'for', 'my', 'birthday'],
#  ['do', 'not', 'do', 'not', 'the', 'couch'],
#  ['yes'],
#  ['okay', 'nice', 'to', 'meet', 'your', 'animals', 'can', 'i', 'see', 'them'],
#  ['what', 'is', 'your', 'favorite', 'candy', 'is'],
#  ['i', 'know', 'i', 'play', 'bevington'],
#  ['are', 'already', 'out', 'and', 'the', 'candy', '2'],
#  ['okay', 'have', 'you', 'chips'],
#  ['okay', 'yes'],
#  ['what',
#   'if',
#   'the',
#   'students',
#   'and',
#   'teachers',
#   'sweated',
#   'rose',
#   'for',
#   'a',
#   'day'],
#  ['no', 'sorry', 'we', 'just', 'have', 'to', 'beg', 'you', 'once'],
#  ['you', 'paint', 'a', 'picture'],
#  ['what', 'is', 'painting', 'the', 'boy'],
#  ['and', 'suka', 'drain'],
#  ['here'],
#  ['she',
#   'is',
#   'or',
#   'small',
#   'she',
#   'is',
#   'not',
#   'often',
#   'in',
#   'the',
#   'woods',
#   'or'],
#  ['yes', 'and', 'do', 'you', 'have', 'brown', 'hair'],
#  ['de'],
#  ['yes'],
#  ['no', 'it', 'is', 'a', 'gift', 't'],
#  ['thanks', 'you'],
#  ['and', 'avoid'],
#  ['i',
#   'see',
#   'unemployed',
#   'a',
#   'girl',
#   'on',
#   'the',
#   'tv',
#   'water',
#   'for',
#   'her'],
#  ['he', 'gets'],
#  ['min', 'is', 'dice', 'football', 'and', 'what', 'is', 'your', 'subject'],
#  ['no',
#   'we',
#   'did',
#   'not',
#   'have',
#   'bonbons',
#   'but',
#   'you',
#   'can',
#   'have',
#   'the',
#   'chocolate',
#   'or',
#   'the',
#   'scheveling',
#   'com'],
#  ['over', 'i', 'think'],
#  ['we',
#   'get',
#   'honey',
#   'from',
#   'it',
#   'and',
#   'not',
#   'just',
#   'honey',
#   'and',
#   'it',
#   'is',
#   'small',
#   'and',
#   'makes',
#   'like',
#   'this',
#   'sound'],
#  ['good', 'do', 'you', 'have', 'candy', 'and', 'donats'],
#  ['to', 'me', 'the', 'funnest', 'joke', 'you', 'know'],
#  ['what', 'is', 'your', 'favorite', 'food'],
#  ['it',
#   'is',
#   'a',
#   'foot',
#   'it',
#   'is',
#   'hall',
#   'round',
#   'and',
#   'it',
#   'is',
#   'yellow'],
#  ['my', 'name', 'is', 'plutal'],
#  ['sir',
#   'so',
#   'did',
#   'you',
#   'want',
#   'a',
#   'special',
#   'flavor',
#   'or',
#   'did',
#   'you',
#   'want',
#   'to',
#   'know',
#   'which',
#   'flavor',
#   'we',
#   'have'],
#  ['what', 'i', 'am', 'doing'],
#  ['i', 'would', 'like', 'to', 'buy', 'some', 'but', 'no', 'one'],
#  ['yes', 'this', 'is', 'a', 'word', 'of', 'it'],
#  ['is',
#   'we',
#   'comes',
#   'with',
#   'this',
#   'man',
#   'of',
#   'transport',
#   'here',
#   'here',
#   'is',
#   'very',
#   'but'],
#  ['my',
#   'favorite',
#   'books',
#   'are',
#   'the',
#   'school',
#   'of',
#   'the',
#   'magic',
#   'animals',
#   'but',
#   'it',
#   'is',
#   'so',
#   'funny',
#   'if',
#   'you',
#   'could',
#   'have',
#   'any',
#   'superpower',
#   'what',
#   'wilt',
#   'it',
#   'be'],
#  ['me', 'too', 'and', 'the', 'hours', 'are', 'on', 'a', 'red', 'things'],
#  ['that'],
#  ['so',
#   'if',
#   'i',
#   'had',
#   'just',
#   'one',
#   'wish',
#   'i',
#   'would',
#   'wish',
#   'for',
#   'that',
#   'i',
#   'could',
#   'be',
#   'a',
#   'popu',
#   'star',
#   'play',
#   'for',
#   'england',
#   'and',
#   'match',
#   'the',
#   'city',
#   'ye',
#   'that',
#   'all',
#   'way'],
#  ['if', 'we', 'do', 'it'],
#  ['ok',
#   'and',
#   'in',
#   'the',
#   'middle',
#   'there',
#   'is',
#   'a',
#   'girl',
#   'mid',
#   'yellow',
#   't',
#   'shirts',
#   'and',
#   'shave',
#   'and',
#   'pine',
#   's'],
#  ['where', 'do', 'he', 'she', 'leave'],
#  ['is', 'it', 'a', 'reporter'],
#  ['no', 'it', 'is', 'black', 'and', 'yellow'],
#  ['yes',
#   'my',
#   'girl',
#   'has',
#   'a',
#   'blue',
#   'tshirt',
#   'and',
#   'a',
#   'violet',
#   'tshirt'],
#  ['t',
#   'we',
#   'cool',
#   'because',
#   'it',
#   'is',
#   'raining',
#   'chocolate',
#   'what',
#   'is',
#   'about',
#   'you'],
#  ['red', 'white', 'and', 'black'],
#  ['okay',
#   'it',
#   'have',
#   'tomato',
#   'and',
#   'mill',
#   'and',
#   'ketchup',
#   'and',
#   'live',
#   'and',
#   'nuts',
#   'and',
#   'had',
#   'shishaldin'],
#  ['thank', 'you'],
#  ['it',
#   'would',
#   'be',
#   'a',
#   'flying',
#   'because',
#   'i',
#   'like',
#   'flying',
#   'also',
#   'with',
#   'the',
#   'plane'],
#  ['tell',
#   'me',
#   'about',
#   'your',
#   'favorite',
#   'thing',
#   'to',
#   'do',
#   'in',
#   'the',
#   'world'],
#  ['in', 'the', 'middle'],
#  ['would',
#   'you',
#   'raider',
#   'run',
#   'away',
#   'from',
#   'a',
#   'line',
#   'or',
#   'a',
#   'bear'],
#  ['school',
#   'i',
#   'like',
#   'to',
#   'play',
#   'no',
#   'in',
#   'the',
#   'holidays',
#   'i',
#   'go',
#   'with',
#   'my',
#   'family',
#   'in',
#   'italy',
#   'eh'],
#  ['like', 'sucker', 'i', 'like', 'sucker', 'ye'],
#  ['my', 'favorite', 'color', 'is', 'purple'],
#  ['guide'],
#  ['now', 'my', 'picture', 'is', 'the', 'red', 'player', 'blue'],
#  ['nice', 'to', 'meet', 'you', 'patrick', 'my', 'name', 'is', 'packman'],
#  ['would',
#   'you',
#   'really',
#   'have',
#   'wings',
#   'like',
#   'a',
#   'breed',
#   'or',
#   'tell',
#   'like',
#   'a',
#   'fish'],
#  ['no',
#   'the',
#   'land',
#   'are',
#   'big',
#   'one',
#   'person',
#   'from',
#   'my',
#   'class',
#   'or',
#   'come',
#   'from',
#   'this',
#   'land'],
#  ['could', 'you', 'say', 'me', 'more', 'detail'],
#  ['no'],
#  ['coffee', 'cup'],
#  ['yes'],
#  ['edition'],
#  ['yes'],
#  ['a', 'guitar'],
#  ['yes', 'and', 'how', 'many'],
#  ['yes'],
#  ['are', 'doing', 'dancing'],
#  ['yes', 'getting', 'what', 'are', 'you', 'doing', 'are', 'you', 'walking'],
#  ['high', 'in', 'the', 'cat', 'in', 'boots', 'what', 'is', 'your', 'name'],
#  ['hello', 'frank', 'what', 'is', 'her', 'hobby'],
#  ['9', 'lollypop'],
#  ['helpful', 'always', 'here', 'and', 'way', 'more'],
#  ['though', 'it', 'does', 'not', 'have', 'proper', 'hers'],
#  ['yes'],
#  ['it', 'is', 'a', 'chicken'],
#  ['top', 'car'],
#  ['this', 'is', 'a', 'getran', 'd'],
#  ['d'],
#  ['say', 'and', 'have', 'you', 'cake'],
#  ['no', 'she', 'is', 'in', 'water', 'and', 'swimming'],
#  ['hello', 'what', 'do', 'you', 'want'],
#  ['hello',
#   'what',
#   'would',
#   'you',
#   'like',
#   'to',
#   'buy',
#   'on',
#   'this',
#   'beautiful',
#   'day'],
#  ['i',
#   'am',
#   'haps',
#   'on',
#   'a',
#   'holiday',
#   'and',
#   'this',
#   'romi',
#   'grandmother',
#   'and',
#   'my',
#   'herand',
#   'this',
#   'is',
#   'cool',
#   'what',
#   'can',
#   'you',
#   'do',
#   'best'],
#  ['yes'],
#  ['does', 'she', 'have', 'long', 'hand'],
#  ['no'],
#  ['me', 'neber'],
#  ['it',
#   'is',
#   'an',
#   'animal',
#   'and',
#   'it',
#   'makes',
#   'funny',
#   'sounds',
#   'and',
#   'it',
#   'is',
#   'mostly',
#   'gray'],
#  ['oh'],
#  ['no', 'do', 'you', 'a', 'child'],
#  ['what', 'are', 'you', 'from'],
#  ['yes', 'in', 'surbiton'],
#  ['i',
#   'love',
#   'chocolate',
#   'true',
#   'what',
#   'if',
#   'the',
#   'students',
#   'and',
#   'teachers',
#   'swapped',
#   'roles',
#   'for',
#   'a',
#   'day',
#   'this',
#   'is',
#   'a',
#   'little',
#   'bit',
#   'a',
#   'way',
#   'has',
#   'these',
#   'questions',
#   'it',
#   'is',
#   '20',
#   'kids',
#   'for',
#   '2',
#   'students',
#   'is',
#   'a',
#   'little',
#   'bit',
#   'i',
#   'do',
#   'not',
#   'like',
#   'this',
#   'idea',
#   'and'],
#  ['k', 'f'],
#  ['yes', 'yah', 'of', 'course'],
#  ['it', 'is', 'a', 'tv'],
#  ['do', 'you', 'have', 'the', 'girl', 'with', 'blue', 'pants'],
#  ['i', 'do', 'not', 'know'],
#  ['i', 'can', 'see', 'a', 'yellow', 'football', 'girl'],
#  ['what', 'you', 'like'],
#  ['if',
#   'he',
#   'could',
#   'go',
#   'into',
#   'space',
#   'what',
#   'would',
#   'it',
#   'take',
#   'very',
#   'god',
#   'pastor',
#   'snores'],
#  ['a',
#   'favorite',
#   'candy',
#   'is',
#   'bounty',
#   'because',
#   'it',
#   'is',
#   'fluffy',
#   'and',
#   'it',
#   'is',
#   'mislike',
#   'chocolate'],
#  ['okay',
#   'cool',
#   'what',
#   'you',
#   'want',
#   'and',
#   'what',
#   'you',
#   'like',
#   'me',
#   'are',
#   'ninas',
#   'or',
#   'pirates'],
#  ['and', 'i', 'drink', 'ice', 'tie', 'and', 'cone', 'okay', 'thank', 'you'],
#  ['i', 'can', 'not', 'see', 'if', 'ire', 'in', 'the', 'can', 'we'],
#  ['okay',
#   'i',
#   'have',
#   'a',
#   'mother',
#   'or',
#   'a',
#   'death',
#   'or',
#   'a',
#   'brother',
#   'a'],
#  ['singing', 'and', 'hate', 'ed'],
#  ['i',
#   'just',
#   'have',
#   'one',
#   'sibling',
#   'named',
#   'peppermint',
#   'and',
#   'he',
#   'loves',
#   'peppermint',
#   'but',
#   'i',
#   'do',
#   'not',
#   'have',
#   'parents',
#   'i',
#   'lost',
#   'them',
#   'long',
#   'time',
#   'ago',
#   'do',
#   'you',
#   'have',
#   'siblings',
#   'or',
#   'a',
#   'family'],
#  ['what', 'to', 'her', 'favorite', 'food'],
#  ['okay', 'maupin'],
#  ['so',
#   'i',
#   'will',
#   'pick',
#   'like',
#   'a',
#   'baby',
#   'lion',
#   'or',
#   'baby',
#   'tiger',
#   'at',
#   'the',
#   'dog'],
#  ['do', 'you', 'have', 'pen', 'cakes'],
#  ['a', 'span', 'his'],
#  ['relation', 'yes', 'it', 'is', 'a', 'rag', 'and', 'sheer', 'm'],
#  ['fly',
#   'in',
#   'the',
#   'sky',
#   'and',
#   'is',
#   'big',
#   'big',
#   'and',
#   'you',
#   'can',
#   'go',
#   'for',
#   'the',
#   'switzerland',
#   'of',
#   'hina',
#   'or',
#   'for',
#   'the',
#   'switzerland',
#   'of',
#   'of',
#   'america'],
#  ['i', 'drink', 'cola', 'and', 'red', 'bull', '2'],
#  ['if',
#   'you',
#   'could',
#   'have',
#   'dinner',
#   'with',
#   'anyone',
#   'or',
#   'would',
#   'you',
#   'close'],
#  ['will', 'you', 'make', 'a', 'sport'],
#  ['is', 'it', 'a', 'go'],
#  ['to',
#   'beach',
#   'would',
#   'you',
#   'raider',
#   'have',
#   'wings',
#   'like',
#   'a',
#   'bird',
#   'or',
#   'a',
#   'tail',
#   'like',
#   'a',
#   'fish'],
#  ['a', 'few', 'chocolates'],
#  ['okay', 'i', 'see', 'them', 'with', 'me', 'is', '20', 'clock'],
#  ['i',
#   'do',
#   'not',
#   'know',
#   'but',
#   'i',
#   'just',
#   'choose',
#   'more',
#   'cats',
#   'and',
#   'a',
#   'dog',
#   'may',
#   'be'],
#  ['your', 'welcome', 'by'],
#  ['and', 'reading', 'lorito'],
#  ['and', 'was'],
#  ['we',
#   'do',
#   'not',
#   'eat',
#   'ice',
#   'cream',
#   'and',
#   'go',
#   'big',
#   'on',
#   'trails'],
#  ['go'],
#  ['and', 'in', 'total', 'is', 'it', '25', 'francs', 'and', 'surficente', 'ok'],
#  ['a', 'monkey'],
#  ['no', 'has', 'you', 'long', 'hair'],
#  ['i', 'can', 'see', 'a', 'b', 'c'],
#  ['is', 'legar'],
#  ['no', 'i', 'eeeeeeears', 'eeeeee', 'eisler'],
#  ['r'],
#  ['i', 'will', 'be', 'a', 'dock', 'er', 'day'],
#  ['nice', 'to', 'meet', 'you', 'too'],
#  ['you', 'are', 'singing'],
#  ['on',
#   'my',
#   'picture',
#   'is',
#   'a',
#   'blue',
#   'tshirt',
#   'and',
#   'blue',
#   'shorts',
#   'and',
#   'red',
#   'shoes',
#   'or',
#   'not',
#   'this',
#   'is',
#   'left',
#   'side',
#   'yes'],
#  ['you',
#   'and',
#   'your',
#   'friends',
#   'always',
#   'do',
#   'it',
#   'in',
#   'the',
#   'break',
#   'time',
#   'in',
#   'recess',
#   'you',
#   'need',
#   'a',
#   'ball',
#   'to',
#   'play',
#   'this',
#   'game',
#   'it',
#   'is',
#   'a',
#   'game',
#   'that',
#   'you',
#   'play',
#   'outside'],
#  ['i', 'do', 'see', 'a', 'camp', 'fire'],
#  ['okay',
#   'der',
#   'condon',
#   '12',
#   'kids',
#   'so',
#   'i',
#   'would',
#   'say',
#   '14',
#   'muffins',
#   'make',
#   'health',
#   'health',
#   'so',
#   '7',
#   'chocolate',
#   'and',
#   '7',
#   'crumb',
#   'please'],
#  ['thank', 'you', 'men'],
#  ['and', 'i', 'brow', 'i', 'brow', '100', 'do'],
#  ['hi'],
#  ['okay', 'this', 'make', '815', 'franks'],
#  ['no', 'i', 'do', 'not', 'have', 'sorry'],
#  ['i', 'smell', 'incli', 'and', 'i', 'go', 'data', 'the', 'sachin'],
#  ['ran'],
#  ['yes',
#   'i',
#   'can',
#   'come',
#   'on',
#   'your',
#   'party',
#   'can',
#   'i',
#   'bring',
#   'food'],
#  ['okay',
#   'the',
#   'of',
#   'the',
#   'bottom',
#   'and',
#   'the',
#   'right',
#   'side',
#   'and',
#   'there',
#   'is',
#   'pink',
#   't',
#   'shirts',
#   'and',
#   'shorts'],
#  ['smug', 'honey', 'and'],
#  ['it', 'is', 'a', 'man', 'or', 'child'],
#  ['is', 'it', 'a', 'train'],
#  ['and', 'has', 'bon', 'bon'],
#  ['it', 'is', 'an', 'insect', 'that', 'can', 'fly'],
#  ['acklin'],
#  ['i',
#   'almost',
#   'did',
#   'not',
#   'see',
#   'it',
#   'i',
#   'do',
#   'see',
#   'a',
#   'girl',
#   'hoose',
#   'or',
#   'a',
#   'boy',
#   'was',
#   'trying',
#   'to',
#   'try',
#   'himself'],
#  ['i', 'have', 'your', 'pancakes'],
#  ['units'],
#  ['would',
#   'you',
#   'rather',
#   'be',
#   'able',
#   'to',
#   'fly',
#   'or',
#   'be',
#   'invisible'],
#  ['and',
#   'in',
#   'free',
#   'time',
#   'i',
#   'like',
#   'to',
#   'change',
#   'my',
#   'color',
#   'a',
#   'little',
#   'bit',
#   'playing',
#   'with',
#   'the',
#   'ball',
#   'and',
#   'with',
#   'repens'],
#  ['banana'],
#  ['and',
#   'it',
#   'eats',
#   'bananas',
#   'it',
#   'is',
#   'climbing',
#   'on',
#   'trees',
#   'it',
#   'is',
#   'jumping',
#   'around',
#   'on',
#   'a',
#   'taken',
#   'roncait',
#   'is',
#   'a',
#   'pet'],
#  ['i', 'am', 'from', 'her', 'so', 'i', 'live', 'like', 'an', 'hit'],
#  ['i',
#   'will',
#   'be',
#   'rather',
#   'to',
#   'fly',
#   'because',
#   'i',
#   'love',
#   'to',
#   'fly',
#   'with',
#   'the',
#   'birds',
#   'and',
#   'go',
#   'in',
#   'the',
#   'clouds',
#   'and',
#   'it',
#   'is',
#   'so',
#   'beautiful',
#   'if',
#   'you',
#   'could',
#   'live',
#   'anywhere',
#   'where',
#   'will',
#   'will',
#   'it',
#   'be',
#   'i',
#   'want',
#   'to',
#   'live',
#   'in',
#   'hawaii',
#   'because',
#   'it',
#   'is',
#   'so',
#   'beautiful',
#   'the',
#   'water',
#   'the',
#   'palmas',
#   'and',
#   'ye',
#   'the',
#   'sun',
#   'shine'],
#  ['okay', 'is', 'it', 'is', 'to'],
#  ['i',
#   'like',
#   'more',
#   'tay',
#   'like',
#   'a',
#   'fish',
#   'because',
#   'i',
#   'like',
#   'water'],
#  ['the',
#   'girl',
#   'has',
#   'pink',
#   'tether',
#   'violet',
#   'pink',
#   'tish',
#   'with',
#   'a',
#   'blue',
#   'bathing',
#   'on'],
#  ['nemine', 'is', 'fries'],
#  ['a', 'home', 'it', 'lets', 'it', 'home'],
#  ['ditty', 'already', 'jump', 'or', 'not'],
#  ['coo', 'like', 'chance', 'collars', 'and', 'i', 'hearts', 'swimming'],
#  ['yes', 'correct'],
#  ['okay', 'then', 'maybe', 'you', 'have', 'matches'],
#  ['note'],
#  ['ka', 'here', 'can', 'i', 'also', 'have', 'cookies'],
#  ['okay', 'it', 'is', 'a', 'home'],
#  ['okay', 'it', 'is', 'good', 'and', 'muffin'],
#  ['nice', 'to', 'meet', 'you'],
#  ['the',
#   'clock',
#   'has',
#   'is',
#   'in',
#   'a',
#   'red',
#   'stuff',
#   'i',
#   'do',
#   'not',
#   'know',
#   'what',
#   'this',
#   'is'],
#  ['tell',
#   'me',
#   'the',
#   'funniest',
#   'joke',
#   'you',
#   'know',
#   'what',
#   'is',
#   'abcd',
#   'e',
#   'f',
#   'g',
#   'what',
#   'is',
#   'wrong',
#   'with',
#   'that',
#   'why',
#   'abcd',
#   'd',
#   'has',
#   'an',
#   'e',
#   'so',
#   'we',
#   'do',
#   'not',
#   'need',
#   'the',
#   'e',
#   'so',
#   'we',
#   'can',
#   'ride',
#   'an',
#   'f',
#   'like',
#   'it',
#   'and',
#   'we',
#   'can',
#   'nobody',
#   'knows',
#   'that',
#   'tell',
#   'me',
#   'about',
#   'your',
#   'happiness',
#   'mim',
#   'i',
#   'got',
#   'at',
#   'southern',
#   'day',
#   'my',
#   'favorite',
#   'memory',
#   'is',
#   'that',
#   'my',
#   'family',
#   'got',
#   'a',
#   'special',
#   'gift',
#   'from',
#   'me',
#   'and',
#   'i',
#   'like',
#   'it',
#   'so',
#   'it',
#   'is',
#   'like',
#   'what',
#   'we',
#   'can',
#   'play',
#   'together',
#   'outside'],
#  ['can', 'we', 'play'],
#  ['and', 'what', 'is', 'your', 'favorite', 'food'],
#  ['u', 's', 'a'],
#  ['no'],
#  ['and',
#   'at',
#   'the',
#   'left',
#   'side',
#   'in',
#   'the',
#   'middle',
#   'there',
#   'is',
#   'a',
#   'picture',
#   'from',
#   'a',
#   'girl'],
#  ['so', 'do', 'you', 'have', 'and', 'do', 'you', 'have', 'peanut', 'better'],
#  ['i',
#   'want',
#   'to',
#   'live',
#   'in',
#   'the',
#   'mountains',
#   'because',
#   'you',
#   'are',
#   'lonely',
#   'and',
#   'in',
#   'the',
#   'window',
#   'you',
#   'can',
#   'make',
#   'winter',
#   'sports',
#   'we',
#   'toboganing',
#   'and',
#   'ski',
#   'and',
#   'in',
#   'the',
#   'summer',
#   'you',
#   'can',
#   'hiking',
#   'in',
#   'the',
#   'mountains',
#   'and',
#   'you',
#   'have',
#   'a',
#   'weary',
#   'fantastic',
#   'whew',
#   'yes'],
#  ['i', 'go', 'to', 'the', 'water', 'park', 'but', 'it', 'is', 'very', 'nice'],
#  ['i', 'can', 'see', '2', 'ice', 'mountains'],
#  ['what', 'is', 'your', 'favorite', 'game', 'to', 'play'],
#  ['i',
#   'will',
#   'go',
#   'to',
#   'cloud',
#   'teleport',
#   'to',
#   'anyway',
#   'world',
#   'where',
#   'were',
#   'you',
#   'go',
#   'you',
#   'go'],
#  ['it', 'is', 'this'],
#  ['yes'],
#  ['i', 'love', 'when', 'i', 'play', 'with', 'my', 'friends', 'and', 'you'],
#  ['pupil', 'means', 'a', 'citron', 'cramberry', 'and', 'chocolate'],
#  ['it', 'is', 'a', 'tree'],
#  ['i',
#   'think',
#   'i',
#   'like',
#   'some',
#   'more',
#   'but',
#   'when',
#   'there',
#   'is',
#   'much',
#   'snow',
#   'i',
#   'like',
#   'winter',
#   'more',
#   'i',
#   'can',
#   'not',
#   'really',
#   'decide'],
#  ['is', 'the', 'car'],
#  ['no', 'you', 'can', 'sit', 'on', 'it'],
#  ['i', 'can', 'see', 'a', 'orange', 'cat'],
#  ['i', 'go', 'to', 'have', 'i', 'yes', 'describe', 'your', 'family'],
#  ['it',
#   'is',
#   'something',
#   'that',
#   'uses',
#   'rotharis',
#   'and',
#   'she',
#   'they',
#   'blow',
#   'in',
#   'that'],
#  ['i',
#   'have',
#   'this',
#   'note',
#   'and',
#   'in',
#   'the',
#   'inter',
#   'ground',
#   'or',
#   'mountains',
#   '5',
#   'mountains'],
#  ['sun', 'sale', 'or', 'water', 'park'],
#  ['in',
#   'my',
#   'picture',
#   'there',
#   'is',
#   'a',
#   'map',
#   'of',
#   'the',
#   'whole',
#   'world'],
#  ['is', 'it'],
#  ['my', 'fame', 'read', 'foot', 'spezza'],
#  ['pickle', 'in'],
#  ['i', 'can', 'see', 'team', 'for', 'players', 'in', 'blue'],
#  ['the', 'also', 'teach'],
#  ['how', 'are', 'we'],
#  ['nice', 'to', 'meet', 'you', 'too'],
#  ['take', 'you'],
#  ['a', 'cat'],
#  ['is', 'it', 'a', 'horse'],
#  ['my', 'father', 'tin', 'is', 'play', 'with', 'friends', 'i'],
#  ['though',
#   'he',
#   'did',
#   'not',
#   'have',
#   'pink',
#   'sin',
#   'chunks',
#   'he',
#   'is',
#   'a',
#   'boy',
#   'who',
#   'has',
#   'blond',
#   'hairs',
#   'and',
#   'has',
#   'red',
#   'swerving',
#   'trunks',
#   'and',
#   'he',
#   'is',
#   'so',
#   'small',
#   'like',
#   'baby'],
#  ['you', 'rate', 'your', 'teacher', 'was', 'a', 'monkey', 'or', 'a', 'panda'],
#  ['yes'],
#  ['yes'],
#  ['if',
#   'you',
#   'had',
#   'a',
#   'ticket',
#   'to',
#   'go',
#   'summer',
#   'where',
#   'would',
#   'you',
#   'go',
#   'i',
#   'would',
#   'go',
#   'to',
#   'this',
#   'is',
#   'a',
#   'hard',
#   'question',
#   'do',
#   'not',
#   'i',
#   'want',
#   'ye',
#   'that',
#   'is',
#   'my',
#   'ticket'],
#  ['i', 'can', 'i', 'can', 'not', 'see'],
#  ['i', 'like', 'that', 'too'],
#  ['trousers', 'no', 'charged', 'trousers'],
#  ['the',
#   'bed',
#   'of',
#   'the',
#   'cat',
#   'on',
#   'their',
#   'right',
#   'side',
#   'at',
#   'the',
#   'bottom',
#   'is',
#   'orange'],
#  ['yes', 'it', 'is'],
#  ['it',
#   'is',
#   'a',
#   'walk',
#   'noyelle',
#   'on',
#   'the',
#   'left',
#   'side',
#   'on',
#   'the',
#   'floor'],
#  ['so', 'what', 'see', 'i', 'see', 'sos', 'call'],
#  ['had', 'a', 'blue', 'jacket'],
#  ['and', 'you'],
#  ['my',
#   'favorite',
#   'candy',
#   'is',
#   'bubble',
#   'because',
#   'i',
#   'do',
#   'not',
#   'know',
#   'because',
#   'it',
#   'is',
#   'so',
#   'how',
#   'bad',
#   'you'],
#  ['as', 'to', 'meet', 'you', 'to'],
#  ['no'],
#  ['this', 'is', 'a', 'instrument', 'and', 'has', 'and'],
#  ['why'],
#  ['sorry', 'but', 'this', 'is', 'already', 'out'],
#  ['i', 'can', 'see', 'see'],
#  ['okay', 'i', 'am', 'getting', 'some', 'for', 'ye'],
#  ['about', 'you', 'know'],
#  ['my', 'favorite', 'foot', 'is', 'pizza', 'and', 'yours'],
#  ['my', 'pleasure'],
#  ['in',
#   'my',
#   'picture',
#   'there',
#   'is',
#   'also',
#   'a',
#   'superhero',
#   'picture',
#   'and'],
#  ['bin', 'see', 'later'],
#  ['it', 'is', 'no', 'and', 'she', 'is', 'moch'],
#  ['and',
#   'in',
#   'red',
#   'circle',
#   'i',
#   'also',
#   'do',
#   'not',
#   'know',
#   'what',
#   'this',
#   'is'],
#  ['yes'],
#  ['it',
#   'would',
#   'be',
#   'to',
#   'fly',
#   'because',
#   'its',
#   'school',
#   'to',
#   'see',
#   'the',
#   'city',
#   'from',
#   'the',
#   'top'],
#  ['and', 'what', 'flavors', 'do', 'or'],
#  ['yes'],
#  ['tell', 'me', 'about', 'something', 'that', 'you', 'love'],
#  ['i',
#   'would',
#   'take',
#   'a',
#   'small',
#   'sore',
#   'baby',
#   'fond',
#   'because',
#   'they',
#   'are',
#   'very',
#   'cute',
#   'and',
#   'you',
#   'can',
#   'brighten',
#   'on',
#   'them'],
#  ['it', 'certainly', 'be'],
#  ['the',
#   'happiest',
#   'day',
#   'i',
#   'do',
#   'not',
#   'know',
#   'when',
#   'i',
#   'was',
#   'born',
#   'and',
#   'you'],
#  ['a', 'bit'],
#  ['this', 'was'],
#  ['can', 'you', 'help', 'you'],
#  ['have', 'you', 'lolly', 'pups'],
#  ['yes'],
#  ['yes'],
#  ['yes'],
#  ['he', 'is', 'small'],
#  ['is', 'it', 'disperse'],
#  ['i',
#   'love',
#   'on',
#   'music',
#   'and',
#   'swinging',
#   'and',
#   'dancing',
#   'and',
#   'you'],
#  ['yes'],
#  ['can'],
#  ['are', 'you', 'are', 'you', 'maybe', 'being', 'quiet'],
#  ['i',
#   'can',
#   'not',
#   'see',
#   'the',
#   'ball',
#   'she',
#   'was',
#   'playing',
#   'football',
#   'olden',
#   'is',
#   'slain',
#   'that',
#   'a',
#   'away',
#   'i',
#   'do',
#   'not',
#   'like',
#   'talk'],
#  ['hello', 'mine', 'am', 'is', 'that', 'is', 'more'],
#  ['my',
#   'favorite',
#   'tv',
#   'show',
#   'is',
#   'zelda',
#   'have',
#   'a',
#   'game',
#   'decade',
#   'and',
#   'i',
#   'love',
#   'this',
#   'cook'],
#  ['up',
#   'in',
#   'the',
#   'mountains',
#   'because',
#   'the',
#   'view',
#   'would',
#   'be',
#   'really',
#   'noise',
#   'tell',
#   'me',
#   'about',
#   'your',
#   'favorite',
#   'tv',
#   'show'],
#  ['yes', 'it', 'is'],
#  ['no', 'it', 'gives', 'them', 'of'],
#  ['and', 'do', 'not', 'you', 'see', 'that'],
#  ['my', 'favorite', 'food', 'is', 'pizza', 'for', 'my', 'dead'],
#  ['my',
#   'favorite',
#   'tell',
#   'me',
#   'about',
#   'your',
#   'favorite',
#   'book',
#   'my',
#   'favorite',
#   'book',
#   'is',
#   'like',
#   'about',
#   'witches',
#   'because',
#   'it',
#   'is',
#   'interesting',
#   'ye',
#   'if',
#   'you',
#   'cut',
#   'have',
#   'any',
#   'superpower',
#   'what',
#   'will',
#   'that',
#   'be',
#   'it',
#   'would',
#   'be',
#   'fire',
#   'power'],
#  ['okay'],
#  ['yes', 'so', 'i', 'want', '3', 'of', 'this'],
#  ['ye', 'is'],
#  ['it', 'is', 'a', 'monkey'],
#  ['mine',
#   'is',
#   'my',
#   'the',
#   'flowers',
#   'in',
#   'the',
#   'picture',
#   'or',
#   'yellow'],
#  ['the', 'boy', 'has', 'a', 'green', 'tshirt'],
#  ['yes', 'and', 'my', 'picture', 'i', 'have', 'a', 'pensile'],
#  ['that', 'different'],
#  ['it', 'is', 'an', 'animal', 'and', 'it', 'do', 'not', 'have', 'arms'],
#  ['and'],
#  ['i',
#   'like',
#   'that',
#   'too',
#   'what',
#   'do',
#   'you',
#   'like',
#   'in',
#   'your',
#   'free',
#   'time'],
#  ['okay', 'and', 'what', 'is', 'your', 'hobby'],
#  ['i', 'am', 'sorry', 'but', 'we', 'have', 'pancakes', 'or', 'crisps'],
#  ['hives'],
#  ['my',
#   'favorite',
#   'tfu',
#   'tfu',
#   'show',
#   'is',
#   'the',
#   'school',
#   'of',
#   'magi',
#   'animals',
#   'this',
#   'is',
#   'weary',
#   'and',
#   'highest',
#   'tell',
#   'me',
#   'something',
#   'magazine',
#   'about',
#   'yourself'],
#  ['you', 'can', 'you', 'can', 'listening', 'music', 'about', 'this'],
#  ['this', 'is', 'a'],
#  ['hello', 'i', 'have', 'questions', 'do', 'you', 'have', 'candies'],
#  ['it',
#   'can',
#   'fly',
#   'but',
#   'it',
#   'is',
#   'no',
#   'animal',
#   'and',
#   'much',
#   'people',
#   'sit',
#   'in',
#   'there',
#   'and',
#   'it',
#   'can',
#   'fly',
#   'quite',
#   'high',
#   'up',
#   'and',
#   'when',
#   'you',
#   'want',
#   'to',
#   'go',
#   'to',
#   'holy',
#   'days',
#   'and',
#   'it',
#   'is',
#   'a',
#   'quite',
#   'long',
#   'way',
#   'you',
#   'often',
#   'go',
#   'with',
#   'that'],
#  ['yes'],
#  ['in',
#   'my',
#   'picture',
#   'there',
#   'is',
#   'also',
#   'a',
#   'bear',
#   'with',
#   'a',
#   'pull',
#   'over',
#   'but',
#   'it',
#   'is',
#   'green',
#   'and',
#   'there',
#   'is',
#   'a',
#   'bear',
#   'on',
#   'the',
#   'left',
#   'side',
#   'and',
#   'he',
#   'has',
#   'yellow',
#   'pink',
#   'and',
#   'blue',
#   'scarf'],
# ...
#  ['this', 'girl', 'i'],
#  ['i',
#   'have',
#   'some',
#   'legal',
#   'from',
#   'them',
#   'but',
#   'i',
#   'not',
#   'so',
#   'big',
#   'fan',
#   'of',
#   'them'],
#  ['i', 'laughed', 'swimming'],
#  ['yes'],
#  ['music', 'books'],
#  ['not',
#   'so',
#   'an',
#   'instrument',
#   'in',
#   'in',
#   'and',
#   'sports',
#   'insanithat',
#   'a',
#   'teacher',
#   'is',
#   'is'],
#  ['my', 'it', 'is', 'rare', 'and', 'driving'],
#  ['is', 'black'],
#  ['coffee'],
#  ['does', 'does', 'it', 'talk', 'with', 'someone'],
#  ['is', 'it', 'this', 'boy'],
#  ['yes'],
#  ['of', 'the'],
#  ['like', 'fun', 'fair', 'best'],
#  ['i',
#   'am',
#   'princess',
#   'speech',
#   'and',
#   'i',
#   'have',
#   'a',
#   'question',
#   'for',
#   'you'],
#  ['the', 'polar', 'bar', 'has', 'here', 'a', 'green', 'plover'],
#  ['amber', 'ponies'],
#  ['i', 'can', 'see', '6', 'balls', 'on', 'the', 'picture'],
#  ['my',
#   'happiest',
#   'memory',
#   'is',
#   'is',
#   'a',
#   'hot',
#   'site',
#   'from',
#   'a',
#   'friend',
#   'and',
#   'you',
#   'tell',
#   'me',
#   'about',
#   'something',
#   'that',
#   'you',
#   'love'],
#  ['no', 'like', 'it', 'yes', 'and', 'you'],
#  ['it', 'is', 'animal'],
#  ['a', 'girl'],
#  ['a', 'newspaper'],
#  ['what', 'are', 'you', 'doing', 'in', 'free', 'time'],
#  ['it', 'has', '6', 'balls', 'on', 'the', 'picture'],
#  ['the', 'rose', 'is', 'pink'],
#  ['if', 'he', 'had', 'one', 'fish', 'what', 'you', 'wish', 'for'],
#  ['describe', 'your', 'best', 'friend'],
#  ['you', 'can', 'do', 'music', 'with'],
#  ['yes', 'an'],
#  ['if',
#   'you',
#   'could',
#   'be',
#   'an',
#   'animal',
#   'for',
#   'a',
#   'day',
#   'which',
#   'one',
#   'would',
#   'you',
#   'like',
#   'to',
#   'be'],
#  ['it', 'is', 'a', 'food', 'this', 'gap', 'with', 'pumas', 'and', 'did'],
#  ['butterman'],
#  ['yellow', 'blue', 'green', 'pink', 'and', 'light', 'blue'],
#  ['i', 'can', 'see', '2', 'clouds'],
#  ['somewhere',
#   'in',
#   'the',
#   'world',
#   'i',
#   'think',
#   'i',
#   'would',
#   'go',
#   'to',
#   'hawaii',
#   'what',
#   'can',
#   'you',
#   'do',
#   'the',
#   'best'],
#  ['as', 'to', 'meet', 'your', 'pins'],
#  ['yes'],
#  ['okay'],
#  ['yes'],
#  ['me', '2'],
#  ['yes'],
#  ['purple', 'is', 'this', 'boy'],
#  ['okay'],
#  ['which', 'book', 'are', 'you', 'ever', 'reading'],
#  ['it',
#   'is',
#   'white',
#   'and',
#   'black',
#   'it',
#   'has',
#   'this',
#   'very',
#   'bitstit',
#   'has',
#   'a',
#   'most',
#   'it',
#   'can',
#   'rolling',
#   'around',
#   'what',
#   'is',
#   'it'],
#  ['very', 'much'],
#  ['i',
#   'am',
#   'from',
#   'the',
#   'root',
#   'factor',
#   'i',
#   'love',
#   'this',
#   'pirate',
#   'smells'],
#  ['yes', 'i', 'am', 'jumping'],
#  ['is', 'a', 'cocod', 'note'],
#  ['singing'],
#  ['green', 'yes'],
#  ['my',
#   'favorite',
#   'thing',
#   'to',
#   'do',
#   'in',
#   'the',
#   'world',
#   'is',
#   'playing',
#   'football',
#   'because',
#   'it',
#   'is',
#   'a',
#   'team',
#   'sport',
#   'and',
#   'it',
#   'is',
#   '0',
#   'france',
#   'it',
#   'is',
#   'rare',
#   'cool',
#   'and',
#   'the',
#   'club',
#   'it',
#   'is',
#   'not',
#   'so',
#   'very',
#   'nice',
#   'because',
#   'the',
#   'most',
#   'weary',
#   'are',
#   'bigger',
#   'than',
#   'me',
#   'and',
#   'then',
#   'i',
#   'am',
#   'a',
#   'little',
#   'over',
#   'romped'],
#  ['and', 'i', 'lost', 'the', 'tool', 'game'],
#  ['yes', '0'],
#  ['yes', 'have', 'you', 'donuts'],
#  ['umbrella'],
#  ['okay',
#   'i',
#   'love',
#   'catch',
#   'chelly',
#   'fishes',
#   'with',
#   'my',
#   'friend',
#   'spunge',
#   'pop',
#   'and',
#   'i',
#   'hate',
#   'bore'],
#  ['and'],
#  ['i', 'can', 'do', 'best', 'play', 'football'],
#  ['my',
#   'best',
#   'friend',
#   'is',
#   'm',
#   'de',
#   'lara',
#   'because',
#   'she',
#   'is',
#   'funny',
#   'she',
#   'understands',
#   'me',
#   'and',
#   'we',
#   'hang',
#   'out',
#   'together',
#   'we',
#   'drink',
#   'la',
#   'and',
#   'drins',
#   'we',
#   'buy',
#   'something',
#   'and'],
#  ['ramangi'],
#  ['great', 'let', 'us', 'go', 'and', 'check', 'out', 'then'],
#  ['i',
#   'can',
#   'see',
#   'a',
#   'girl',
#   'i',
#   'think',
#   'wants',
#   'to',
#   'make',
#   'a',
#   'goal',
#   'with',
#   'brown',
#   'hair'],
#  ['yes'],
#  ['but', 'we', 'have', 'pancakes', 'or', 'breze'],
#  ['ok'],
#  ['there'],
#  ['no', 'it', 'is', 'not', 'an', 'animal', 'it', 'is', 'not', 'a', 'person'],
#  ['i',
#   'love',
#   'football',
#   'and',
#   'swim',
#   'and',
#   'into',
#   'winter',
#   'snowboarding'],
#  ['yes'],
#  ['is', 'it', 'a', 'hat'],
#  ['in', 'or', 'castle'],
#  ['the', 'boy', 'and', 'the', 'boys', 'in', 'the', 'big', 'pool'],
#  ['you', 'have', 'it', 'over', 'the', 'hoof'],
#  ['behind', 'of', 'the', 'boy', 'and', 'the', 'girl', 'is', '123'],
#  ['and',
#   'and',
#   'why',
#   'i',
#   'say',
#   'this',
#   'for',
#   'rubbish',
#   'and',
#   'you',
#   'can',
#   'put',
#   'it',
#   'as',
#   'a',
#   'skid',
#   'bachiller',
#   'and',
#   'we',
#   'could',
#   'put',
#   'a',
#   'carton',
#   'rubbish'],
#  ['if',
#   'you',
#   'could',
#   'be',
#   'an',
#   'animal',
#   'for',
#   'a',
#   'day',
#   'which',
#   'one',
#   'would',
#   'you',
#   'like',
#   'to',
#   'be'],
#  ['yes'],
#  ['i', 'see', 'a', 'boy', 'with', 'white', 'shirt', 'and', 'red', 'hot'],
#  ['earning', 'because', 'of', 'i', 'like', 'fighting'],
#  ['it',
#   'is',
#   'a',
#   'ionu',
#   'and',
#   'it',
#   'is',
#   'all',
#   'colors',
#   'and',
#   'brown',
#   'black'],
#  ['no',
#   'the',
#   'vomen',
#   'name',
#   'crish',
#   'is',
#   'in',
#   'the',
#   'morning',
#   'and',
#   'have'],
#  ['i', 'live', 'in', 'a', 'house', 'what', 'you', 'love'],
#  ['which', 'call', 'a', 'colonite', '0', 'or', 'normal'],
#  ['i',
#   'can',
#   'eat',
#   'this',
#   'it',
#   'is',
#   'on',
#   'meat',
#   'and',
#   'when',
#   'she',
#   'lies',
#   'it',
#   'is',
#   'picking',
#   'corns'],
#  ['tell', 'me', 'about', 'your', 'favorite', 'tv', 'show'],
#  ['it', 'is', 'more', 'on', 'the', 'top'],
#  ['have', 'a', 'nice', 'day'],
#  ['the', 'tapir', 'is', 'yellow'],
#  ['b'],
#  ['a', 'cat'],
#  ['will',
#   'you',
#   'rather',
#   'be',
#   'a',
#   'dog',
#   'for',
#   'a',
#   'day',
#   'or',
#   'a',
#   'cat',
#   'for',
#   'a',
#   'day'],
#  ['yet', 'is', 'this', 'monkey', 'burton'],
#  ['i',
#   'have',
#   'come',
#   'in',
#   'on',
#   'a',
#   'fire',
#   'i',
#   'can',
#   'see',
#   'i',
#   'can',
#   'see',
#   '4',
#   'kids',
#   'with',
#   'blue',
#   'shirts',
#   'and',
#   'cute',
#   'hosen'],
#  ['you', 'well', 'come', 'by'],
#  ['as', 'he', 'for', 'kids', 'with', 'blue', 'outfit'],
#  ['my', 'name', 'is', 'momo', 'and', 'what', 'is', 'your', 'name'],
#  ['what', 'can', 'you', 'repeat', 'e'],
#  ['maybe',
#   'but',
#   'it',
#   'is',
#   'all',
#   'right',
#   'so',
#   'do',
#   'you',
#   'have',
#   'a',
#   'pet',
#   'at',
#   'home'],
#  ['in',
#   'my',
#   'picture',
#   'the',
#   'scarf',
#   'of',
#   'the',
#   'bear',
#   'on',
#   'the',
#   'bottom',
#   'right',
#   'is',
#   'yellow',
#   'blue',
#   'pink',
#   'light',
#   'blue',
#   'pink',
#   'blue',
#   'yellow',
#   'light',
#   'blue',
#   'blue',
#   'yellow',
#   'green',
#   'blue'],
#  ['by'],
#  ['i', 'be', 'a', 'bird'],
#  ['okay'],
#  ['note'],
#  ['yeah',
#   'i',
#   'know',
#   'what',
#   'you',
#   'mean',
#   'so',
#   'on',
#   'the',
#   'couch',
#   'i',
#   'mean',
#   'and',
#   'the',
#   'girl',
#   'on',
#   'your',
#   'picture',
#   'holds',
#   'something',
#   'like',
#   'i',
#   'mean',
#   'i',
#   'do',
#   'not',
#   'know',
#   'what',
#   'it',
#   'is',
#   'so',
#   'yeah',
#   'but',
#   'yeah',
#   'she',
#   'is',
#   'holding',
#   'something',
#   'on',
#   'european',
#   'picture',
#   'by',
#   'nypicturese',
#   'she',
#   'is',
#   'holding',
#   'this',
#   'not',
#   's'],
#  ['i', 'have', 'not'],
#  ['what', 'flavor', 'of', 'christ', 'do', 'you', 'have', 'natural'],
#  ['mine',
#   'is',
#   'an',
#   'basketball',
#   'because',
#   'we',
#   'really',
#   'have',
#   'to',
#   'consecrate',
#   'where',
#   'the',
#   'sport',
#   'like',
#   'the',
#   'odor',
#   'times',
#   'and',
#   'stuff'],
#  ['it',
#   'can',
#   'be',
#   'yellow',
#   'can',
#   'be',
#   'orange',
#   'it',
#   'can',
#   'be',
#   'black',
#   'can',
#   'be',
#   'gray'],
#  ['it',
#   'is',
#   'it',
#   'is',
#   'peak',
#   'it',
#   'hit',
#   'it',
#   'has',
#   'wings',
#   'it',
#   'can',
#   'fly'],
#  ['does', 'he', 'have', 'a', 'blue', 'jacket'],
#  ['a', 'skater', 'toting'],
#  ['no'],
#  ['my', 'favorite', 'eat', 'is', 'sushi'],
#  ['my',
#   'grandma',
#   'is',
#   'good',
#   'okay',
#   'and',
#   'what',
#   'will',
#   'happen',
#   'is',
#   'it',
#   'rained',
#   'candy',
#   'inside',
#   'of',
#   'the',
#   'water'],
#  ['rocket', 'record', 'in'],
#  ['okay',
#   'it',
#   'is',
#   'something',
#   'that',
#   'you',
#   'can',
#   'use',
#   'in',
#   'school',
#   'it',
#   'is',
#   'starting',
#   'with',
#   'a',
#   'data',
#   'b',
#   'and',
#   'literally',
#   'almost',
#   'everybody',
#   'use',
#   'you',
#   'anybody',
#   'uses',
#   'this',
#   'object',
#   'and',
#   'it',
#   'is',
#   'very',
#   'useful',
#   'for',
#   'school',
#   'and',
#   'literally',
#   'everybody',
#   'has',
#   'it',
#   'i'],
#  ['muffins',
#   'muffins',
#   'yea',
#   'we',
#   'go',
#   'muffins',
#   'what',
#   'kind',
#   'of',
#   'muffins',
#   'would',
#   'you',
#   'like',
#   'to',
#   'have'],
#  ['i',
#   'am',
#   'jumping',
#   'for',
#   'fun',
#   'it',
#   'ca',
#   'now',
#   'how',
#   'are',
#   'you',
#   'kicking',
#   'someone'],
#  ['some', 'death', '0'],
#  ['yes', 'but', 'actually', 'it', 'is', 'a', 'boy'],
#  ['die'],
#  ['it', 'is', 'a', 'borger'],
#  ['yes'],
#  ['it',
#   'has',
#   'much',
#   'leaves',
#   'and',
#   'its',
#   'bake',
#   'some',
#   'animals',
#   'living',
#   'there'],
#  ['okay', 'thanks', 'you'],
#  ['and', 'have', 'you', 'apples'],
#  ['yes', 'correct'],
#  ['the', 'house'],
#  ['and', 'aiken', 'ze', 'girl', 'she', 'has', 'red', 'tish'],
#  ['it', 'is', 'a', 'photo', 'camera'],
#  ['i', 'see', 'a', 'boy', 'and', 'a', 'girl'],
#  ['it',
#   'would',
#   'be',
#   'kind',
#   'of',
#   'weird',
#   'because',
#   'you',
#   'would',
#   'go',
#   'to',
#   'the',
#   'class',
#   'and',
#   'see',
#   'all',
#   'the',
#   'teachers',
#   'in',
#   'it',
#   'and',
#   'ask',
#   'you',
#   'a',
#   'question',
#   'like',
#   'how',
#   'does',
#   'i',
#   'i',
#   'do',
#   'not',
#   'know',
#   'for',
#   'questions',
#   'like',
#   'you',
#   'should',
#   'ask',
#   'the',
#   'question',
#   'it',
#   'is',
#   'kind',
#   'of',
#   'wield',
#   'if',
#   'you',
#   'could',
#   'have',
#   'any',
#   'superpowers',
#   'what',
#   'would',
#   'it',
#   'be'],
#  ['terry'],
#  ['no'],
#  ['5', 'peg'],
#  ['then',
#   'we',
#   'have',
#   'a',
#   'fellow',
#   'what',
#   'color',
#   'is',
#   'your',
#   'son',
#   'up',
#   'bright'],
#  ['it', 'is', 'a', 'football'],
#  ['m', 'this', 'i', 'have'],
#  ['my',
#   'fame',
#   'favorite',
#   'wid',
#   'you',
#   'go',
#   'in',
#   'this',
#   'fortnight',
#   'my',
#   'favorite',
#   'bridge',
#   'feel',
#   'is',
#   'lightly',
#   'a'],
#  ['on', 'my', 'picture', 'is', 'on', 'the', 'black', 'board', 'abc'],
#  ['television'],
#  ['yes'],
#  ['as', 'i', 'ran', 'in'],
#  ['god', 'by'],
#  ['pope'],
#  ['how', 'many', 'clouds', 'are', 'on', 'the', 'picture', 't'],
#  ['at'],
#  ['here', 'we', 'do'],
#  ['on',
#   'these',
#   'things',
#   'i',
#   'can',
#   'show',
#   'films',
#   'and',
#   'it',
#   'is',
#   'not',
#   'so',
#   'big',
#   'and',
#   'what',
#   'is',
#   'it'],
#  ['oh'],
#  ['this',
#   'thinks',
#   'i',
#   'can',
#   'play',
#   'a',
#   'game',
#   'and',
#   'that',
#   'game',
#   'has',
#   '11',
#   'persons',
#   '11',
#   'brothers',
#   '11',
#   'persons',
#   'are',
#   'playing',
#   'in',
#   'this',
#   'game',
#   'and',
#   'what',
#   'is',
#   'it'],
#  ['i',
#   'need',
#   'a',
#   'dog',
#   'for',
#   'every',
#   'time',
#   'because',
#   'i',
#   'have',
#   'a',
#   'dog',
#   'and',
#   'cat',
#   'are',
#   'also',
#   'cool',
#   'because',
#   'because',
#   'i',
#   'love',
#   'dogs',
#   'much'],
#  ['no'],
#  ['he', 'and', 'yanzi'],
#  ['would',
#   'your',
#   'raider',
#   'be',
#   'able',
#   'to',
#   'fly',
#   'or',
#   'be',
#   'in',
#   'reserve'],
#  ['yes', 'it', 'is', 'a', 'bird'],
#  ['of',
#   'how',
#   'many',
#   'so',
#   'we',
#   'feel',
#   'a',
#   'pouen',
#   'as',
#   'venice',
#   'sage',
#   'in',
#   'a',
#   'poking',
#   'hot',
#   's',
#   'and',
#   'the',
#   'ring',
#   'vile'],
#  ['my', 'is', 'red'],
#  ['okay'],
#  ['not', 'so', 'good'],
#  ['all',
#   'my',
#   'things',
#   'that',
#   'i',
#   'am',
#   'worry',
#   'about',
#   'not',
#   'having',
#   'if',
#   'you',
#   'could',
#   'have',
#   'dinner',
#   'with',
#   'anyone',
#   'who',
#   'would',
#   'you',
#   'choose'],
#  ['he', 'now'],
#  ['you', 'can', 'lick', 'the', 'time', 'ok'],
#  ['not'],
#  ['if',
#   'you',
#   'could',
#   'have',
#   'dinner',
#   'with',
#   'any',
#   'more',
#   'full',
#   'futures'],
#  ['i',
#   'like',
#   'to',
#   'go',
#   'swim',
#   'in',
#   'the',
#   'water',
#   'because',
#   'it',
#   'is',
#   'cold',
#   'and',
#   'outside',
#   'it',
#   'is',
#   'warm'],
#  ['green', 'was', 'all', 'it', 'is', 'a', 'different'],
#  ['if',
#   'you',
#   'are',
#   'could',
#   'have',
#   'any',
#   'superpower',
#   'what',
#   'would',
#   'it',
#   'be'],
#  ['my', 'favorite', 'food', 'is', 'potatoes', 'where', 'does', 'she', 'live'],
#  ['or', 'you', 'want', 'to', 'hang', 'out', 'with', 'micky', 'mouse'],
#  ['hello',
#   'my',
#   'name',
#   'is',
#   'pluto',
#   'my',
#   'favorite',
#   'animal',
#   'is',
#   'a',
#   'horse',
#   'it',
#   'is',
#   'big',
#   'it',
#   'has',
#   '4',
#   'legs',
#   'it',
#   'lives',
#   'in',
#   'switzerland',
#   'canada',
#   'england',
#   'germany',
#   'and',
#   'europe',
#   'i',
#   'can',
#   'write',
#   'good',
#   'home'],
#  ['do', 'you', 'have', 'muffins'],
#  ['it',
#   'is',
#   'black',
#   'and',
#   'has',
#   '4',
#   'legs',
#   'it',
#   'can',
#   'jump',
#   'really',
#   'high',
#   'and',
#   'it',
#   'can',
#   'jump',
#   'really',
#   'really',
#   'high',
#   'down'],
#  ['an', 'ipod'],
#  ['no', 'really', 'have', 'you', 'mouth', 'c'],
#  ['my',
#   'favorite',
#   'sport',
#   'this',
#   'handball',
#   'i',
#   'play',
#   'in',
#   'a',
#   'club',
#   'handball',
#   'and',
#   '33',
#   'times',
#   'per',
#   'week',
#   'handball',
#   'training',
#   'and',
#   'i',
#   'love',
#   'this',
#   'sport',
#   'and',
#   'i',
#   'have',
#   'very',
#   'nice',
#   'friends',
#   'in',
#   'this',
#   'sport',
#   'club',
#   'and',
#   'i',
#   'love',
#   'this'],
#  ['it', 'is', 'a', 'house', 'that', 'is'],
#  ['tell',
#   'me',
#   'about',
#   'you',
#   'favorite',
#   'thing',
#   'to',
#   'do',
#   'into',
#   'world'],
#  ['no', 'and', 'it', 'is', 'a'],
#  ['okay',
#   'a',
#   'ducat',
#   'if',
#   'you',
#   'could',
#   'have',
#   'any',
#   'animal',
#   'as',
#   'a',
#   'pet',
#   'what',
#   'would',
#   'it',
#   'be'],
#  ['okay', 'pye'],
#  ['okay', 'and', 'have', 'you', 'muffins'],
#  ['ninshas', 'or', 'pirates'],
#  ['now', 'and', 'is', 'called'],
#  ['do', 'you', 'have', 'a', 'bird', 'up', 'left'],
#  ['yes'],
#  ['no'],
#  ['me', 'too', 'and', 'my', 'white', 'board', 'are', 'white'],
#  ['you',
#   'are',
#   'really',
#   'close',
#   'something',
#   'in',
#   'the',
#   'intro',
#   'from',
#   'simpson',
#   'is',
#   'it',
#   'is',
#   'something',
#   'that',
#   'you',
#   'sit',
#   'and',
#   'it',
#   'is',
#   'soft'],
#  ['as', 'pedlers', 'are', 'c'],
#  ['yes'],
#  ['my', 'favorite', 'foot', 'is', 'fish'],
#  ['i', 'live', 'in', 'the', 'house', 'i', 'hate', 'my', 'sister'],
#  ['okay',
#   'on',
#   'my',
#   'picture',
#   'i',
#   'have',
#   'a',
#   'boy',
#   'with',
#   'brown',
#   'hair',
#   'i'],
#  ['come', 'in'],
#  ['we', 'have'],
#  ['tesla', 'what', 'does', 'he', 'love', 'and', 'hate', 'dying'],
#  ['thank', 'you', 'it', 'is', 'great', 'i'],
#  ['bars', 'lie'],
#  ['i',
#   'can',
#   'see',
#   'also',
#   '2',
#   'tulips',
#   'but',
#   'deck',
#   'yellow',
#   'and',
#   'i',
#   'can',
#   'see',
#   'a',
#   'picture',
#   'green',
#   'grass',
#   'and',
#   'blue',
#   'sky',
#   'and',
#   'yellow',
#   'sun'],
#  ['i', 'live', 'in', 'turkey', 'and'],
#  ['yes'],
#  ['is',
#   'he',
#   'playing',
#   'is',
#   'he',
#   'playing',
#   'in',
#   'here',
#   'so',
#   'spilt',
#   'soda'],
#  ['miles',
#   'in',
#   'a',
#   'rocket',
#   'began',
#   'legenille',
#   'tell',
#   'me',
#   'up',
#   'put',
#   'you',
#   'pist',
#   'mary'],
#  ['now',
#   'and',
#   'and',
#   'as',
#   'caved',
#   'as',
#   'in',
#   'restaurants',
#   'and',
#   'promised',
#   'to',
#   'a'],
#  ['i',
#   'do',
#   'not',
#   'see',
#   'a',
#   'blue',
#   'team',
#   'but',
#   'i',
#   'see',
#   'a',
#   'pink',
#   'team'],
#  ['a', 'plan', 'to', 'have', 'a', 'an', 'down', 'pestre'],
#  ['i',
#   'will',
#   'be',
#   'a',
#   'dog',
#   'but',
#   'the',
#   'dogs',
#   'are',
#   'so',
#   'funny',
#   'for',
#   'me',
#   'the',
#   'beach',
#   'all',
#   'the',
#   'bush'],
#  ['good', 'and', 'have', 'you', 'can', 'you'],
#  ['the', 'cat', 'in', 'my', 'picture', 'is', 'white'],
#  ['ah'],
#  ['thank', 'you'],
#  ['beach', 'recure', 's'],
#  ['have', 'you', 'one', 'pack', 'strawberry', 'pancakes'],
#  ['but', 'what', 'is', 'your', 'favorite', 'food'],
#  ['it', 'is', 'a', 'snake'],
#  ['are', 'you', 'sitting'],
#  ['no', 'you', 'can', 'drive', 'it'],
#  ['have', 'your', 'man', 'a', 'green', 'shirt'],
#  ['no'],
#  ['i',
#   'spared',
#   'with',
#   'my',
#   'little',
#   'eye',
#   'and',
#   'some',
#   'one',
#   'girl',
#   'wild',
#   'and',
#   'too',
#   'many',
#   'things',
#   'in',
#   'a',
#   'hat'],
#  ['this', 'animal', 'likes', 'bananas', 'it', 'climbs'],
#  ...)

# %% [markdown]
# We have some transcripts that are empty -- we should deal with that!!!
#
# Also, deal with situations when the sentences are too long.

# %%
n=0
for sentence, words in zip(tr_stt_transcripts, tr_stt_words):
    if len(words) == 0: continue
    if len(words)>75:
        n+=1
        continue
    encode_sentence(sentence, words, model_bert, tokenizer)
n
# Out:
# 47

# %% [markdown]
# There are 47 really long sentences. We should perhaps split them into multiple. I will see about the strategies tomorrow.
